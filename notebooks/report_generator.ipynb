# %%
from utils.notebook_setup import setup_project
setup_project()

from herbarium_processor.core.analysis.html_report_generator import HTMLReportGenerator


canonical_csv_path = "/Users/danielleward/Downloads/cs_canonical2.csv"
test_csv_path = "/Users/danielleward/Downloads/student.csv" 
html_output_path = "tmp/test_imports.html" 


reporter = HTMLReportGenerator(
    canonical_csv_path=canonical_csv_path,
    test_csv_path=test_csv_path,
    html_output_path=html_output_path
)

reporter.run_all()
# Out:
# Notebook root set to /Users/danielleward/Documents/Projects/herbarium-processor
#
# 🧠 Model Similarity Summary
# ✅ Percentage of identical fields: 72.3%
#
# 📊 Per column identical:
#                                     accuracy
# label_header                             0.7
# scientific_name                          0.2
# field_collection_location_verbatim       0.2
# county                                   0.7
# state                                    0.5
# country                                  1.0
# verbatim_latitude                        0.8
# verbatim_longitude                       0.8
# elevation                                0.4
# habitat_information                      0.5
# field_collection_date                    0.1
# comment                                  0.7
# field_collectors                         0.7
# field_collection_number                  1.0
# identifier                               0.9
# identification_date                      0.8
# exsiccatae                               0.9
# associated_taxa                          1.0
# old_scientific_name                      1.0
# old_identifier                           1.0
# old_identification_date                  1.0
# verbatim_identification_date             1.0
# <button onclick="toggleSampleDiffView()">Toggle Diff View</button>
# <script>
# function toggleSampleDiffView() {
#     const origTables = document.querySelectorAll('.sample-orig-table');
#     const diffTables = document.querySelectorAll('.sample-diff-table');
#     for (let i = 0; i < origTables.length; i++) {
#         if (origTables[i].style.display === 'none') {
#             origTables[i].style.display = '';
#             diffTables[i].style.display = 'none';
#         } else {
#             origTables[i].style.display = 'none';
#             diffTables[i].style.display = '';
#         }
#     }
# }
# </script>
# <h4>❌ Sample Mismatches in Column: label_header</h4><table class='sample-orig-table' border='1' style='border-collapse:collapse;font-family:sans-serif;font-size:14px;'><tr><th style='padding:4px;'>ID</th><th style='padding:4px;'>Test Value</th><th style='padding:4px;'>Canonical Value</th></tr><tr><td style='padding:4px;'>UC1631606</td><td style='padding:4px;'>Bryophytes of Australia</td><td style='padding:4px;'>BRYOPHYTES OF AUSTRALIA STATE OF Queensland</td></tr><tr><td style='padding:4px;'>UC1920256</td><td style='padding:4px;'>Bryophytes of Iran</td><td style='padding:4px;'>Bryophytes of Iran Golestan Province</td></tr><tr><td style='padding:4px;'>UC769360</td><td style='padding:4px;'></td><td style='padding:4px;'>NEW ZEALAND MOSSES FROM THE HERBARIUM OF G. O. K. SAINSBURY</td></tr></table><table class='sample-diff-table' border='1' style='border-collapse:collapse;font-family:sans-serif;font-size:14px; display:none;'><tr><th style='padding:4px;'>ID</th><th style='padding:4px;' colspan='2'>Diff (test vs canonical)</th></tr><tr><td style='padding:4px;'>UC1631606</td><td style='padding:4px;' colspan='2'><span class='arrow-view' style='display:none'>Bryophytes of Australia<br><small><i>→ BRYOPHYTES OF AUSTRALIA STATE OF Queensland</i></small></span><span class='diff-view'>B<span style="background-color:#ffcccc">r</span><span style="background-color:#ffcccc">y</span><span style="background-color:#ffcccc">o</span><span style="background-color:#ffcccc">p</span><span style="background-color:#ffcccc">h</span><span style="background-color:#ffcccc">y</span><span style="background-color:#ffcccc">t</span><span style="background-color:#ffcccc">e</span><span style="background-color:#ffcccc">s</span><span style="background-color:#ccffcc">R</span><span style="background-color:#ccffcc">Y</span><span style="background-color:#ccffcc">O</span><span style="background-color:#ccffcc">P</span><span style="background-color:#ccffcc">H</span><span style="background-color:#ccffcc">Y</span><span style="background-color:#ccffcc">T</span><span style="background-color:#ccffcc">E</span><span style="background-color:#ccffcc">S</span> <span style="background-color:#ffcccc">o</span><span style="background-color:#ffcccc">f</span><span style="background-color:#ccffcc">O</span><span style="background-color:#ccffcc">F</span> A<span style="background-color:#ccffcc">U</span><span style="background-color:#ccffcc">S</span><span style="background-color:#ccffcc">T</span><span style="background-color:#ccffcc">R</span><span style="background-color:#ccffcc">A</span><span style="background-color:#ccffcc">L</span><span style="background-color:#ccffcc">I</span><span style="background-color:#ccffcc">A</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">S</span><span style="background-color:#ccffcc">T</span><span style="background-color:#ccffcc">A</span><span style="background-color:#ccffcc">T</span><span style="background-color:#ccffcc">E</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">O</span><span style="background-color:#ccffcc">F</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">Q</span>u<span style="background-color:#ccffcc">e</span><span style="background-color:#ccffcc">e</span><span style="background-color:#ccffcc">n</span>s<span style="background-color:#ccffcc">l</span><span style="background-color:#ffcccc">t</span><span style="background-color:#ffcccc">r</span>a<span style="background-color:#ccffcc">n</span><span style="background-color:#ccffcc">d</span><span style="background-color:#ffcccc">l</span><span style="background-color:#ffcccc">i</span><span style="background-color:#ffcccc">a</span><br><small><i>→ BRYOPHYTES OF AUSTRALIA STATE OF Queensland</i></small></span></td></tr><tr><td style='padding:4px;'>UC1920256</td><td style='padding:4px;' colspan='2'><span class='arrow-view' style='display:none'>Bryophytes of Iran<br><small><i>→ Bryophyte ...
# <button onclick="toggleDiffView()">Toggle Diff View</button>
# <script>
# function toggleDiffView() {
#     const arrow = document.querySelectorAll('.arrow-view');
#     const diff = document.querySelectorAll('.diff-view');
#     for (let i = 0; i < arrow.length; i++) {
#         if (arrow[i].style.display === 'none') {
#             arrow[i].style.display = 'inline';
#             diff[i].style.display = 'none';
#         } else {
#             arrow[i].style.display = 'none';
#             diff[i].style.display = 'inline';
#         }
#     }
# }
# </script>
# <table border="1" style="border-collapse: collapse; font-family: sans-serif; font-size: 14px;"><tr><th style="padding: 6px;">ID</th><th style="padding: 6px;">label_header</th><th style="padding: 6px;">scientific_name</th><th style="padding: 6px;">field_collection_location_verbatim</th><th style="padding: 6px;">county</th><th style="padding: 6px;">state</th><th style="padding: 6px;">country</th><th style="padding: 6px;">verbatim_latitude</th><th style="padding: 6px;">verbatim_longitude</th><th style="padding: 6px;">elevation</th><th style="padding: 6px;">habitat_information</th><th style="padding: 6px;">field_collection_date</th><th style="padding: 6px;">comment</th><th style="padding: 6px;">field_collectors</th><th style="padding: 6px;">field_collection_number</th><th style="padding: 6px;">identifier</th><th style="padding: 6px;">identification_date</th><th style="padding: 6px;">exsiccatae</th><th style="padding: 6px;">associated_taxa</th><th style="padding: 6px;">old_scientific_name</th><th style="padding: 6px;">old_identifier</th><th style="padding: 6px;">old_identification_date</th><th style="padding: 6px;">verbatim_identification_date</th></tr><tr><td style="padding: 4px;"><b>UC1026554</b><br><a href="https://lichenportal.org/portal/collections/individual/index.php?occid=UC1026554" target="_blank">🔗</a></td><td style="background-color: #fffd80; color: #000; font-weight: bold; padding: 4px;"><span class='arrow-view'>K. H. et F. RECHINGER, ITER IRANICUM II, 1948<br><small><i>→ K. H. et F. RECHINGER, ITER IRANICUM II., 1948</i></small></span><span class='diff-view' style='display:none'>K. H. et F. RECHINGER, ITER IRANICUM II<span style="background-color:#ccffcc">.</span>, 1948<br><small><i>→ K. H. et F. RECHINGER, ITER IRANICUM II., 1948</i></small></span></td><td style="background-color: #ffee80; color: #000; font-weight: bold; padding: 4px;"><span class='arrow-view'>Hypnum Vaucheri Lesqu.<br><small><i>→ Hypnum vaucheri Lesq.</i></small></span><span class='diff-view' style='display:none'>Hypnum <span style="background-color:#ffcccc">V</span><span style="background-color:#ccffcc">v</span>aucheri Lesq<span style="background-color:#ffcccc">u</span>.<br><small><i>→ Hypnum vaucheri Lesq.</i></small></span></td><td style="background-color: #ffce80; color: #000; font-weight: bold; padding: 4px;"><span class='arrow-view'>In declivibus borealibus montium Shahvar prope Hadjilang,<br><small><i>→ Prov. Gorgan (Asterabad): In declivibus borealibus montium Shahvar prope Hadjilang</i></small></span><span class='diff-view' style='display:none'><span style="background-color:#ccffcc">P</span><span style="background-color:#ccffcc">r</span><span style="background-color:#ccffcc">o</span><span style="background-color:#ccffcc">v</span><span style="background-color:#ccffcc">.</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">G</span><span style="background-color:#ccffcc">o</span><span style="background-color:#ccffcc">r</span><span style="background-color:#ccffcc">g</span><span style="background-color:#ccffcc">a</span><span style="background-color:#ccffcc">n</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">(</span><span style="background-color:#ccffcc">A</span><span style="background-color:#ccffcc">s</span><span style="background-color:#ccffcc">t</span><span style="background-color:#ccffcc">e</span><span style="background-color:#ccffcc">r</span><span style="background-color:#ccffcc">a</span><span style="background-color:#ccffcc">b</span><span style="background-color:#ccffcc">a</span><span style="background-color:#ccffcc">d</span><span style="background-color:#ccffcc">)</span><span style="background-color:#ccffcc">:</span><span style="background-color:#ccffcc"> </span>In declivibus borealibus montium Shahvar prope Hadjilang<span style="background-color:#ffcccc">,</span><br><small><i>→ Prov. Gorgan (Asterabad): In declivibus borealibus montium Shahvar prope Hadjilang< ...
