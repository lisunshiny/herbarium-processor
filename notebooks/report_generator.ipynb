# %%
# two line thing that liann said needs to be included 

canonical_csv_path = "data/canonical.csv"
html_output_path = "tmp/test_imports.html"
output_csv_path = "tmp/an_output.csv"
system_instructions = ""
