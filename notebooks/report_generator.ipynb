# %%
from utils.notebook_setup import setup_project
setup_project()

from herbarium_processor.core.analysis.html_report_generator import HTMLReportGenerator


canonical_csv_path = "/Users/danielleward/Downloads/random_sample.csv"
test_csv_path = "/Users/danielleward/Downloads/model_generated.csv" 
html_output_path = "tmp/test_imports.html" 


reporter = HTMLReportGenerator(
    canonical_csv_path=canonical_csv_path,
    test_csv_path=test_csv_path,
    html_output_path=html_output_path
)

reporter.run_all()
# Out:
# Notebook root set to /Users/danielleward/Documents/Projects/herbarium-processor
#
# 🧠 Model Similarity Summary
# ✅ Percentage of identical fields: 85.7%
#
# 📊 Per column identical:
#                                     accuracy
# label_header                           0.800
# scientific_name                        0.800
# field_collection_location_verbatim     0.867
# county                                 0.600
# state                                  1.000
# country                                0.400
# verbatim_latitude                      1.000
# verbatim_longitude                     1.000
# elevation                              1.000
# habitat_information                    0.867
# field_collection_date                  0.667
# comment                                0.733
# field_collectors                       0.800
# field_collection_number                0.933
# identifier                             0.933
# identification_date                    1.000
# exsiccatae                             0.867
# associated_taxa                        0.867
# old_scientific_name                    1.000
# old_identifier                         0.933
# old_identification_date                0.933
# <button onclick="toggleSampleDiffView()">Toggle Diff View</button>
# <script>
# function toggleSampleDiffView() {
#     const origTables = document.querySelectorAll('.sample-orig-table');
#     const diffTables = document.querySelectorAll('.sample-diff-table');
#     for (let i = 0; i < origTables.length; i++) {
#         if (origTables[i].style.display === 'none') {
#             origTables[i].style.display = '';
#             diffTables[i].style.display = 'none';
#         } else {
#             origTables[i].style.display = 'none';
#             diffTables[i].style.display = '';
#         }
#     }
# }
# </script>
# <h4>❌ Sample Mismatches in Column: label_header</h4><table class='sample-orig-table' border='1' style='border-collapse:collapse;font-family:sans-serif;font-size:14px;'><tr><th style='padding:4px;'>ID</th><th style='padding:4px;'>Test Value</th><th style='padding:4px;'>Canonical Value</th></tr><tr><td style='padding:4px;'>UC1067286</td><td style='padding:4px;'>LICHENS OF CALIFORNIA.</td><td style='padding:4px;'>HERB. UNIVERSITY OF CALIFORNIA. LICHENS OF CALIFORNIA.</td></tr><tr><td style='padding:4px;'>UC1998090</td><td style='padding:4px;'>ANDERSON AND SHUSHAN:</td><td style='padding:4px;'>ANDERSON AND SHUSHAN: LICHENS OF WESTERN NORTH AMERICA NO. 124</td></tr><tr><td style='padding:4px;'>UC43241</td><td style='padding:4px;'></td><td style='padding:4px;'>W. W. CALKINS' NORTH AMERICAN LICHENS.</td></tr></table><table class='sample-diff-table' border='1' style='border-collapse:collapse;font-family:sans-serif;font-size:14px; display:none;'><tr><th style='padding:4px;'>ID</th><th style='padding:4px;' colspan='2'>Diff (test vs canonical)</th></tr><tr><td style='padding:4px;'>UC1067286</td><td style='padding:4px;' colspan='2'><span class='arrow-view' style='display:none'>LICHENS OF CALIFORNIA.<br><small><i>→ HERB. UNIVERSITY OF CALIFORNIA. LICHENS OF CALIFORNIA.</i></small></span><span class='diff-view'><span style="background-color:#ccffcc">H</span><span style="background-color:#ccffcc">E</span><span style="background-color:#ccffcc">R</span><span style="background-color:#ccffcc">B</span><span style="background-color:#ccffcc">.</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">U</span><span style="background-color:#ccffcc">N</span><span style="background-color:#ccffcc">I</span><span style="background-color:#ccffcc">V</span><span style="background-color:#ccffcc">E</span><span style="background-color:#ccffcc">R</span><span style="background-color:#ccffcc">S</span><span style="background-color:#ccffcc">I</span><span style="background-color:#ccffcc">T</span><span style="background-color:#ccffcc">Y</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">O</span><span style="background-color:#ccffcc">F</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">C</span><span style="background-color:#ccffcc">A</span><span style="background-color:#ccffcc">L</span><span style="background-color:#ccffcc">I</span><span style="background-color:#ccffcc">F</span><span style="background-color:#ccffcc">O</span><span style="background-color:#ccffcc">R</span><span style="background-color:#ccffcc">N</span><span style="background-color:#ccffcc">I</span><span style="background-color:#ccffcc">A</span><span style="background-color:#ccffcc">.</span><span style="background-color:#ccffcc"> </span>LICHENS OF CALIFORNIA.<br><small><i>→ HERB. UNIVERSITY OF CALIFORNIA. LICHENS OF CALIFORNIA.</i></small></span></td></tr><tr><td style='padding:4px;'>UC1998090</td><td style='padding:4px;' colspan='2'><span class='arrow-view' style='display:none'>ANDERSON AND SHUSHAN:<br><small><i>→ ANDERSON AND SHUSHAN: LICHENS OF WESTERN NORTH AMERICA NO. 124</i></small></span><span class='diff-view'>ANDERSON AND SHUSHAN:<span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">L</span><span style="background-color:#ccffcc">I</span><span style="background-color:#ccffcc">C</span><span style="background-color:#ccffcc">H</span><span style="background-color:#ccffcc">E</span><span style="background-color:#ccffcc">N</span><span style="background-color:#ccffcc">S</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">O</span><span style="background-color:#ccffcc">F</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">W</span><span style="background-color:#ccffcc">E</span><span style="background-color:#ccffcc">S</span><span style="background-color:#ccffcc">T</span><span style="ba ...
# <button onclick="toggleDiffView()">Toggle Diff View</button>
# <script>
# function toggleDiffView() {
#     const arrow = document.querySelectorAll('.arrow-view');
#     const diff = document.querySelectorAll('.diff-view');
#     for (let i = 0; i < arrow.length; i++) {
#         if (arrow[i].style.display === 'none') {
#             arrow[i].style.display = 'inline';
#             diff[i].style.display = 'none';
#         } else {
#             arrow[i].style.display = 'none';
#             diff[i].style.display = 'inline';
#         }
#     }
# }
# </script>
# <table border="1" style="border-collapse: collapse; font-family: sans-serif; font-size: 14px;"><tr><th style="padding: 6px;">ID</th><th style="padding: 6px;">label_header</th><th style="padding: 6px;">scientific_name</th><th style="padding: 6px;">field_collection_location_verbatim</th><th style="padding: 6px;">county</th><th style="padding: 6px;">state</th><th style="padding: 6px;">country</th><th style="padding: 6px;">verbatim_latitude</th><th style="padding: 6px;">verbatim_longitude</th><th style="padding: 6px;">elevation</th><th style="padding: 6px;">habitat_information</th><th style="padding: 6px;">field_collection_date</th><th style="padding: 6px;">comment</th><th style="padding: 6px;">field_collectors</th><th style="padding: 6px;">field_collection_number</th><th style="padding: 6px;">identifier</th><th style="padding: 6px;">identification_date</th><th style="padding: 6px;">exsiccatae</th><th style="padding: 6px;">associated_taxa</th><th style="padding: 6px;">old_scientific_name</th><th style="padding: 6px;">old_identifier</th><th style="padding: 6px;">old_identification_date</th></tr><tr><td style="padding: 4px;"><b>UC1067286</b><br><a href="https://lichenportal.org/portal/collections/individual/index.php?occid=UC1067286" target="_blank">🔗</a></td><td style="background-color: #ff9480; color: #000; font-weight: bold; padding: 4px;"><span class='arrow-view'>LICHENS OF CALIFORNIA.<br><small><i>→ HERB. UNIVERSITY OF CALIFORNIA. LICHENS OF CALIFORNIA.</i></small></span><span class='diff-view' style='display:none'><span style="background-color:#ccffcc">H</span><span style="background-color:#ccffcc">E</span><span style="background-color:#ccffcc">R</span><span style="background-color:#ccffcc">B</span><span style="background-color:#ccffcc">.</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">U</span><span style="background-color:#ccffcc">N</span><span style="background-color:#ccffcc">I</span><span style="background-color:#ccffcc">V</span><span style="background-color:#ccffcc">E</span><span style="background-color:#ccffcc">R</span><span style="background-color:#ccffcc">S</span><span style="background-color:#ccffcc">I</span><span style="background-color:#ccffcc">T</span><span style="background-color:#ccffcc">Y</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">O</span><span style="background-color:#ccffcc">F</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">C</span><span style="background-color:#ccffcc">A</span><span style="background-color:#ccffcc">L</span><span style="background-color:#ccffcc">I</span><span style="background-color:#ccffcc">F</span><span style="background-color:#ccffcc">O</span><span style="background-color:#ccffcc">R</span><span style="background-color:#ccffcc">N</span><span style="background-color:#ccffcc">I</span><span style="background-color:#ccffcc">A</span><span style="background-color:#ccffcc">.</span><span style="background-color:#ccffcc"> </span>LICHENS OF CALIFORNIA.<br><small><i>→ HERB. UNIVERSITY OF CALIFORNIA. LICHENS OF CALIFORNIA.</i></small></span></td><td style="background-color: #e6ffe6; color: #000; padding: 4px;">Fuscopannaria coralloidea P.M. Jørg.</td><td style="background-color: #e6ffe6; color: #000; padding: 4px;">Mt. Tamalpais</td><td style="background-color: #e6ffe6; color: #000; padding: 4px;"></td><td style="background-color: #e6ffe6; color: #000; padding: 4px;">California</td><td style="background-color: #e6ffe6; color: #000; padding: 4px;">United States</td><td style="background-color: #e6ffe6; color: #000; padding: 4px;"></td><td style="background-color: #e6ffe6; color: #000; padding: 4px;"></td><td style="background-color: #e6ffe6; color: #000; padding: 4px;"></td><td style="background-color: #e6ffe6; color: #000; padding: 4px;"></td><td style="background-color: #ffea80; color: #000; font-weight: bold; padding: 4px;"><span class='arrow-view'>12 Apr 1893<br><sma ...
