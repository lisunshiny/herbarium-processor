# %%
"""
Herbarium Processor Notebook
========================

This notebook is designed to process herbarium specimen images and generate labels using a prompt-based approach.
It includes steps for image processing, prompt configuration, and generating specimen labels.
It is structured to be run in a Jupyter notebook environment.

Configuration: select what images to sample from.

You should edit this section each time you run the code to:
  * select the images you want to process
  * set the path to the output CSV file.
"""

from utils.notebook_setup import setup_project
setup_project()

image_path = "/Users/danielleward/Downloads/images"
output_csv_path = "tmp/an_output.csv"
# Out:
# Notebook root set to /Users/danielleward/Documents/Projects/herbarium-processor

# %%
"""
Configuration: setting up the prompts and system instructions for Gemini inference.

You do NOT need to edit this section.
"""
from herbarium_processor.core.inference.prompt_factory import create_prompt_builder_from_yaml

system_instructions_path = "prompts/ocr_system_instructions_no_citations.md"
prompt_builder = create_prompt_builder_from_yaml("prompts/configs/default_prompt.yaml")

print('Prompt:')
print(prompt_builder.generate_debug_prompt())
# Out:
# Prompt:
# You are an AI assistant trained to extract structured data from herbarium specimen label images.
#
# You will be shown 3 label images and corresponding OCR blocks as examples. These examples include the correct structured JSON output. After that, you will be shown a fourth image (with OCR blocks) that you must process.
#
# Use both the image and the OCR output to extract only the following 21 fields as a valid JSON object using `snake_case` keys:
#
# * `label_header`
# * `scientific_name`
# * `field_collection_location_verbatim`
# * `county`
# * `state`
# * `country`
# * `verbatim_latitude`
# * `verbatim_longitude`
# * `elevation`
# * `habitat_information`
# * `field_collection_date`
# * `comment`
# * `field_collectors`
# * `field_collection_number`
# * `identifier`
# * `identification_date`
# * `exsiccatae`
# * `associated_taxa`
# * `old_scientific_name`
# * `old_identifier`
# * `old_identification_date`
#
#
# Return `null` for any field that is not clearly present or legible. Do **not** infer or fabricate any information. Do **not** return extra fields.
#
# ---
# **Example 1**
#
# Image:
# <|image_0|>
#
# OCR Output:
# ```json
# [
#   {
#     "average_confidence": 0.9735246280000001,
#     "bounding_box": [
#       {
#         "x": 229,
#         "y": 175
#       },
#       {
#         "x": 839,
#         "y": 175
#       },
#       {
#         "x": 839,
#         "y": 211
#       },
#       {
#         "x": 229,
#         "y": 211
#       }
#     ],
#     "id": "1.1.1",
#     "text": "F. RENAULD \u0026 J. CARDOT"
#   },
#   {
#     "average_confidence": 0.9616529533333332,
#     "bounding_box": [
#       {
#         "x": 175,
#         "y": 237
#       },
#       {
#         "x": 890,
#         "y": 237
#       },
#       {
#         "x": 890,
#         "y": 287
#       },
#       {
#         "x": 175,
#         "y": 287
#       }
#     ],
#     "id": "1.1.2",
#     "text": "Musci europ\u00e6i exsiccati"
#   },
#   {
#     "average_confidence": 0.5832276,
#     "bounding_box": [
#       {
#         "x": 531,
#         "y": 301
#       },
#       {
#         "x": 597,
#         "y": 301
#       },
#       {
#         "x": 597,
#         "y": 315
#       },
#       {
#         "x": 531,
#         "y": 315
#       }
#     ],
#     "id": "1.1.3",
#     "text": "303"
#   },
#   {
#     "average_confidence": 0.831805994,
#     "bounding_box": [
#       {
#         "x": 151,
#         "y": 360
#       },
#       {
#         "x": 920,
#         "y": 360
#       },
#       {
#         "x": 920,
#         "y": 445
#       },
#       {
#         "x": 151,
#         "y": 445
#       }
#     ],
#     "id": "1.1.4",
#     "text": "N\u00ba30 . Fontinalis arvernica Ren-"
#   },
#   {
#     "average_confidence": 0.9345777649999999,
#     "bounding_box": [
#       {
#         "x": 86,
#         "y": 470
#       },
#       {
#         "x": 888,
#         "y": 470
#       },
#       {
#         "x": 888,
#         "y": 549
#       },
#       {
#         "x": 86,
#         "y": 549
#       }
#     ],
#     "id": "1.1.5",
#     "text": "In aquis profundis lacus Pavin Arverniae"
#   },
#   {
#     "average_confidence": 0.828987095,
#     "bounding_box": [
#       {
#         "x": 460,
#         "y": 553
#       },
#       {
#         "x": 873,
#         "y": 553
#       },
#       {
#         "x": 873,
#         "y": 642
#       },
#       {
#         "x": 460,
#         "y": 642
#       }
#     ],
#     "id": "1.1.6",
#     "text": "Leg . F. Renauld"
#   },
#   {
#     "average_confidence": 0.6125826249999999,
#     "bounding_box": [
#       {
#         "x": 69,
#         "y": 740
#       },
#       {
#         "x": 722,
#         "y": 740
#       },
#       {
#         "x": 722,
#         "y": 844
#       },
#       {
#         "x": 69,
#         "y": 844
#       }
#     ],
#     "id": "1.1.7",
#     "text": "Fontinalis autifystica"
#   },
#   {
#     "average_confidence": 0.44124288333333334,
#     "bounding_box": [
#       {
#         "x": 736,
#         "y": 783
#       },
#       {
#         "x": 856,
#         "y": 783
#       },
#       {
#         "x": 856,
#         "y": 852
#       },
#       {
#         "x": 736,
#         "y": 852
#       }
#     ],
#     "id": "1.1.8",
#     "text": "[ . ]"
#   },
#   {
#     "average_confidence": 0.802025325,
#     "bounding_box": [
#       {
#         "x": 71,
#         "y": 819
#       },
#       {
#         "x": 246,
#         "y": 819
#       },
#       {
#         "x": 246,
#         "y": 859
#       },
#       {
#         "x": 71,
#         "y": 859
#       }
#     ],
#     "id": "1.1.9",
#     "text": "Hedw ."
#   },
#   {
#     "average_confidence": 0.9705295266666667,
#     "bounding_box": [
#       {
#         "x": 98,
#         "y": 877
#       },
#       {
#         "x": 880,
#         "y": 877
#       },
#       {
#         "x": 880,
#         "y": 915
#       },
#       {
#         "x": 98,
#         "y": 915
#       }
#     ],
#     "id": "1.1.10",
#     "text": "Determined by Winona H. Welch 8-14-1945"
#   },
#   {
#     "average_confidence": 0.67041407,
#     "bounding_box": [
#       {
#         "x": 70,
#         "y": 915
#       },
#       {
#         "x": 142,
#         "y": 915
#       },
#       {
#         "x": 142,
#         "y": 938
#       },
#       {
#         "x": 70,
#         "y": 938
#       }
#     ],
#     "id": "1.1.11",
#     "text": "30 ."
#   }
# ]
# ```
#
# Correct Output:
# ```json
# {
#   "associated_taxa": null,
#   "comment": "In aquis profundis",
#   "country": "France",
#   "county": null,
#   "elevation": null,
#   "exsiccatae": "Musci europ\u00e6i exsiccati",
#   "field_collection_date": null,
#   "field_collection_location_verbatim": "lacus Pavin Arverniae",
#   "field_collection_number": "30",
#   "field_collectors": "[\u0027F. Renauld\u0027]",
#   "habitat_information": null,
#   "identification_date": "14-Aug-45",
#   "identifier": "Winona H. Welch",
#   "label_header": "F. RENAULD \u0026 J. CARDOT",
#   "old_identification_date": null,
#   "old_identifier": "Ren.",
#   "old_scientific_name": "Fontinalis avernica",
#   "scientific_name": "Fontinalis antipyretica Hedw.",
#   "state": null,
#   "verbatim_latitude": null,
#   "verbatim_longitude": null
# }
# ```
#
# ---
# **Example 2**
#
# Image:
# <|image_1|>
#
# OCR Output:
# ```json
# [
#   {
#     "average_confidence": 0.984642865,
#     "bounding_box": [
#       {
#         "x": 300,
#         "y": 94
#       },
#       {
#         "x": 606,
#         "y": 94
#       },
#       {
#         "x": 606,
#         "y": 127
#       },
#       {
#         "x": 300,
#         "y": 127
#       }
#     ],
#     "id": "1.1.1",
#     "text": "MUSCI JAPONICI"
#   },
#   {
#     "average_confidence": 0.9760597423076922,
#     "bounding_box": [
#       {
#         "x": 76,
#         "y": 158
#       },
#       {
#         "x": 828,
#         "y": 158
#       },
#       {
#         "x": 828,
#         "y": 187
#       },
#       {
#         "x": 76,
#         "y": 187
#       }
#     ],
#     "id": "1.1.2",
#     "text": "Ser . 9 ( 1955 ) Edited by A. Noguchi \u0026 S. Hattori"
#   },
#   {
#     "average_confidence": 0.9795091333333333,
#     "bounding_box": [
#       {
#         "x": 74,
#         "y": 248
#       },
#       {
#         "x": 434,
#         "y": 248
#       },
#       {
#         "x": 434,
#         "y": 274
#       },
#       {
#         "x": 74,
#         "y": 274
#       }
#     ],
#     "id": "1.1.3",
#     "text": "420. Fontinalis antipyretica"
#   },
#   {
#     "average_confidence": 0.971444046,
#     "bounding_box": [
#       {
#         "x": 446,
#         "y": 250
#       },
#       {
#         "x": 582,
#         "y": 250
#       },
#       {
#         "x": 582,
#         "y": 274
#       },
#       {
#         "x": 446,
#         "y": 274
#       }
#     ],
#     "id": "1.1.4",
#     "text": "( L. ) Hedw ."
#   },
#   {
#     "average_confidence": 0.9811021606666667,
#     "bounding_box": [
#       {
#         "x": 76,
#         "y": 365
#       },
#       {
#         "x": 830,
#         "y": 365
#       },
#       {
#         "x": 830,
#         "y": 393
#       },
#       {
#         "x": 76,
#         "y": 393
#       }
#     ],
#     "id": "1.1.5",
#     "text": "Rocks submerged in stream , ca. 1500 m . alt . , near Azumi ,"
#   },
#   {
#     "average_confidence": 0.985448875,
#     "bounding_box": [
#       {
#         "x": 76,
#         "y": 398
#       },
#       {
#         "x": 316,
#         "y": 398
#       },
#       {
#         "x": 316,
#         "y": 424
#       },
#       {
#         "x": 76,
#         "y": 424
#       }
#     ],
#     "id": "1.1.6",
#     "text": "Nagano Prefecture"
#   },
#   {
#     "average_confidence": 0.7980332,
#     "bounding_box": [
#       {
#         "x": 801,
#         "y": 428
#       },
#       {
#         "x": 829,
#         "y": 428
#       },
#       {
#         "x": 829,
#         "y": 453
#       },
#       {
#         "x": 801,
#         "y": 453
#       }
#     ],
#     "id": "1.1.7",
#     "text": "OF"
#   },
#   {
#     "average_confidence": 0.9351292653333334,
#     "bounding_box": [
#       {
#         "x": 74,
#         "y": 428
#       },
#       {
#         "x": 860,
#         "y": 428
#       },
#       {
#         "x": 860,
#         "y": 471
#       },
#       {
#         "x": 74,
#         "y": 471
#       }
#     ],
#     "id": "1.1.8",
#     "text": "Coll . U. Mizushima ( Mrs. ) , September 29 , 1954 HERBARIUM OF THE"
#   },
#   {
#     "average_confidence": 0.68084073,
#     "bounding_box": [
#       {
#         "x": 750,
#         "y": 462
#       },
#       {
#         "x": 828,
#         "y": 462
#       },
#       {
#         "x": 828,
#         "y": 500
#       },
#       {
#         "x": 750,
#         "y": 500
#       }
#     ],
#     "id": "1.1.9",
#     "text": "UC"
#   },
#   {
#     "average_confidence": 0.9760237975,
#     "bounding_box": [
#       {
#         "x": 74,
#         "y": 479
#       },
#       {
#         "x": 290,
#         "y": 479
#       },
#       {
#         "x": 290,
#         "y": 506
#       },
#       {
#         "x": 74,
#         "y": 506
#       }
#     ],
#     "id": "1.1.10",
#     "text": "Det . A. Noguchi"
#   },
#   {
#     "average_confidence": 0.8101489133333333,
#     "bounding_box": [
#       {
#         "x": 698,
#         "y": 490
#       },
#       {
#         "x": 860,
#         "y": 490
#       },
#       {
#         "x": 860,
#         "y": 534
#       },
#       {
#         "x": 698,
#         "y": 534
#       }
#     ],
#     "id": "1.1.11",
#     "text": "FIERSITY OF CALIFOR"
#   },
#   {
#     "average_confidence": 0.7194973,
#     "bounding_box": [
#       {
#         "x": 332,
#         "y": 566
#       },
#       {
#         "x": 444,
#         "y": 566
#       },
#       {
#         "x": 444,
#         "y": 676
#       },
#       {
#         "x": 332,
#         "y": 676
#       }
#     ],
#     "id": "1.1.12",
#     "text": "UNIVERS"
#   },
#   {
#     "average_confidence": 0.9516384499999999,
#     "bounding_box": [
#       {
#         "x": 392,
#         "y": 570
#       },
#       {
#         "x": 593,
#         "y": 570
#       },
#       {
#         "x": 593,
#         "y": 602
#       },
#       {
#         "x": 392,
#         "y": 602
#       }
#     ],
#     "id": "1.1.13",
#     "text": "M 207518"
#   },
#   {
#     "average_confidence": 0.8396531,
#     "bounding_box": [
#       {
#         "x": 536,
#         "y": 559
#       },
#       {
#         "x": 669,
#         "y": 559
#       },
#       {
#         "x": 669,
#         "y": 680
#       },
#       {
#         "x": 536,
#         "y": 680
#       }
#     ],
#     "id": "1.1.14",
#     "text": "CALIFORNIA"
#   },
#   {
#     "average_confidence": 0.9783724,
#     "bounding_box": [
#       {
#         "x": 486,
#         "y": 653
#       },
#       {
#         "x": 522,
#         "y": 653
#       },
#       {
#         "x": 522,
#         "y": 672
#       },
#       {
#         "x": 486,
#         "y": 672
#       }
#     ],
#     "id": "1.1.15",
#     "text": "OF"
#   }
# ]
# ```
#
# Correct Output:
# ```json
# {
#   "associated_taxa": null,
#   "comment": "Ser. 9 (1955) Edited by A. Noguchi \u0026 S. Hattori",
#   "country": "Japan",
#   "county": null,
#   "elevation": "ca. 1500 m.",
#   "exsiccatae": null,
#   "field_collection_date": "29-Sep-54",
#   "field_collection_location_verbatim": "near Azumi",
#   "field_collection_number": null,
#   "field_collectors": "[\u0027U. Mizushima (Mrs.)\u0027]",
#   "habitat_information": "Rocks submerged in stream",
#   "identification_date": null,
#   "identifier": "A. Noguchi",
#   "label_header": "MUSCI JAPONICI",
#   "old_identification_date": null,
#   "old_identifier": null,
#   "old_scientific_name": null,
#   "scientific_name": "Fontinalis antipyretica (L.) Hedw.",
#   "state": "Nagano Prefecture",
#   "verbatim_latitude": null,
#   "verbatim_longitude": null
# }
# ```
#
# ---
# **Example 3**
#
# Image:
# <|image_2|>
#
# OCR Output:
# ```json
# [
#   {
#     "average_confidence": 0.9877717,
#     "bounding_box": [
#       {
#         "x": 469,
#         "y": 38
#       },
#       {
#         "x": 630,
#         "y": 38
#       },
#       {
#         "x": 630,
#         "y": 62
#       },
#       {
#         "x": 469,
#         "y": 62
#       }
#     ],
#     "id": "1.1.1",
#     "text": "Duplicatum ex"
#   },
#   {
#     "average_confidence": 0.9869702433333334,
#     "bounding_box": [
#       {
#         "x": 344,
#         "y": 75
#       },
#       {
#         "x": 763,
#         "y": 75
#       },
#       {
#         "x": 763,
#         "y": 100
#       },
#       {
#         "x": 344,
#         "y": 100
#       }
#     ],
#     "id": "1.1.2",
#     "text": "CONSERVATORIO BOTANICO GENEVENSI"
#   },
#   {
#     "average_confidence": 0.99032766,
#     "bounding_box": [
#       {
#         "x": 493,
#         "y": 120
#       },
#       {
#         "x": 602,
#         "y": 120
#       },
#       {
#         "x": 602,
#         "y": 136
#       },
#       {
#         "x": 493,
#         "y": 136
#       }
#     ],
#     "id": "1.1.3",
#     "text": "HELVETIAE"
#   },
#   {
#     "average_confidence": 0.88217158,
#     "bounding_box": [
#       {
#         "x": 280,
#         "y": 168
#       },
#       {
#         "x": 490,
#         "y": 168
#       },
#       {
#         "x": 490,
#         "y": 192
#       },
#       {
#         "x": 280,
#         "y": 192
#       }
#     ],
#     "id": "1.1.4",
#     "text": "390 . Fontinalis"
#   },
#   {
#     "average_confidence": 0.9535369380000001,
#     "bounding_box": [
#       {
#         "x": 502,
#         "y": 171
#       },
#       {
#         "x": 796,
#         "y": 171
#       },
#       {
#         "x": 796,
#         "y": 199
#       },
#       {
#         "x": 502,
#         "y": 199
#       }
#     ],
#     "id": "1.1.5",
#     "text": "antipyretica L. ex Hedw ."
#   },
#   {
#     "average_confidence": 0.9365827622222223,
#     "bounding_box": [
#       {
#         "x": 202,
#         "y": 218
#       },
#       {
#         "x": 710,
#         "y": 218
#       },
#       {
#         "x": 710,
#         "y": 246
#       },
#       {
#         "x": 202,
#         "y": 246
#       }
#     ],
#     "id": "1.1.6",
#     "text": "Loc .: Suisse . Vaud . Commune de Chavannes"
#   },
#   {
#     "average_confidence": 0.9293862388888888,
#     "bounding_box": [
#       {
#         "x": 288,
#         "y": 230
#       },
#       {
#         "x": 844,
#         "y": 230
#       },
#       {
#         "x": 844,
#         "y": 274
#       },
#       {
#         "x": 288,
#         "y": 274
#       }
#     ],
#     "id": "1.1.7",
#     "text": "Cours de la Versoix ( rivi\u00e8re des Bois ."
#   },
#   {
#     "average_confidence": 0.9901602,
#     "bounding_box": [
#       {
#         "x": 638,
#         "y": 250
#       },
#       {
#         "x": 658,
#         "y": 250
#       },
#       {
#         "x": 658,
#         "y": 274
#       },
#       {
#         "x": 638,
#         "y": 274
#       }
#     ],
#     "id": "1.1.8",
#     "text": ") ."
#   },
#   {
#     "average_confidence": 0.8883680110000001,
#     "bounding_box": [
#       {
#         "x": 200,
#         "y": 272
#       },
#       {
#         "x": 846,
#         "y": 272
#       },
#       {
#         "x": 846,
#         "y": 303
#       },
#       {
#         "x": 200,
#         "y": 303
#       }
#     ],
#     "id": "1.1.9",
#     "text": "Leg . S. Vautier et J - D . Bersier"
#   },
#   {
#     "average_confidence": 0.9210517628571429,
#     "bounding_box": [
#       {
#         "x": 199,
#         "y": 296
#       },
#       {
#         "x": 734,
#         "y": 296
#       },
#       {
#         "x": 734,
#         "y": 326
#       },
#       {
#         "x": 199,
#         "y": 326
#       }
#     ],
#     "id": "1.1.10",
#     "text": "Date : 1 juin 1964 . Alt"
#   },
#   {
#     "average_confidence": 0.9414688275,
#     "bounding_box": [
#       {
#         "x": 736,
#         "y": 310
#       },
#       {
#         "x": 842,
#         "y": 310
#       },
#       {
#         "x": 842,
#         "y": 330
#       },
#       {
#         "x": 736,
#         "y": 330
#       }
#     ],
#     "id": "1.1.11",
#     "text": ". 464 m ."
#   },
#   {
#     "average_confidence": 0.960434021111111,
#     "bounding_box": [
#       {
#         "x": 199,
#         "y": 337
#       },
#       {
#         "x": 757,
#         "y": 337
#       },
#       {
#         "x": 757,
#         "y": 370
#       },
#       {
#         "x": 199,
#         "y": 370
#       }
#     ],
#     "id": "1.1.12",
#     "text": "Obs .: Sur les pierres submerg\u00e9es dans le lit"
#   },
#   {
#     "average_confidence": 0.9866670000000001,
#     "bounding_box": [
#       {
#         "x": 286,
#         "y": 350
#       },
#       {
#         "x": 832,
#         "y": 350
#       },
#       {
#         "x": 832,
#         "y": 388
#       },
#       {
#         "x": 286,
#         "y": 388
#       }
#     ],
#     "id": "1.1.13",
#     "text": "rivi\u00e8re de la"
#   },
#   {
#     "average_confidence": 0.9415124,
#     "bounding_box": [
#       {
#         "x": 374,
#         "y": 371
#       },
#       {
#         "x": 382,
#         "y": 371
#       },
#       {
#         "x": 382,
#         "y": 387
#       },
#       {
#         "x": 374,
#         "y": 387
#       }
#     ],
#     "id": "1.1.14",
#     "text": "."
#   },
#   {
#     "average_confidence": 0.9880059133333333,
#     "bounding_box": [
#       {
#         "x": 418,
#         "y": 564
#       },
#       {
#         "x": 610,
#         "y": 564
#       },
#       {
#         "x": 610,
#         "y": 616
#       },
#       {
#         "x": 418,
#         "y": 616
#       }
#     ],
#     "id": "1.1.15",
#     "text": "HERBARIUM OF THE"
#   },
#   {
#     "average_confidence": 0.7149779,
#     "bounding_box": [
#       {
#         "x": 386,
#         "y": 610
#       },
#       {
#         "x": 463,
#         "y": 610
#       },
#       {
#         "x": 463,
#         "y": 686
#       },
#       {
#         "x": 386,
#         "y": 686
#       }
#     ],
#     "id": "1.1.16",
#     "text": "CNIVER"
#   },
#   {
#     "average_confidence": 0.9897582,
#     "bounding_box": [
#       {
#         "x": 447,
#         "y": 610
#       },
#       {
#         "x": 581,
#         "y": 610
#       },
#       {
#         "x": 581,
#         "y": 644
#       },
#       {
#         "x": 447,
#         "y": 644
#       }
#     ],
#     "id": "1.1.17",
#     "text": "1318628"
#   }
# ]
# ```
#
# Correct Output:
# ```json
# {
#   "associated_taxa": null,
#   "comment": null,
#   "country": "Switzerland",
#   "county": null,
#   "elevation": "464 m.",
#   "exsiccatae": "Duplicatum ex CONSERVATORIO BOTANICO GENEVENSI HELVETIAE",
#   "field_collection_date": "1-Jun-64",
#   "field_collection_location_verbatim": "Vaud. Commune de Chavannes des Bois. Cours de la Versoix (rivi\u00e8re).",
#   "field_collection_number": "390",
#   "field_collectors": "[\u0027S. Vautier\u0027, \u0027J-D. Bersier\u0027]",
#   "habitat_information": "Sur les pierres submerg\u00e9es dans le lit de la rivi\u00e8re.",
#   "identification_date": "16-Aug-45",
#   "identifier": "Winona H. Welch",
#   "label_header": null,
#   "old_identification_date": null,
#   "old_identifier": null,
#   "old_scientific_name": null,
#   "scientific_name": "Fontinalis antipyretica L. ex Hedw.",
#   "state": "Vaud",
#   "verbatim_latitude": null,
#   "verbatim_longitude": null
# }
# ```
#
#
# ---
#
# **Now classify this image:**
#
# Image:
# <|image_3|>
#
# OCR Output:
# ```json
# {}
# ```
#
# Return your output as a single valid JSON object with **only the fields listed above**. Be precise. Do not guess unknown fields.

# %%
"""
Step 1: Image processing.

Take the .heic images from the phone and convert them to .jpg format.
This step also includes resizing the images to a standard size and doing any necessary preprocessing.

You do NOT need to edit this section.
"""

from herbarium_processor.core.image.image_utils import (
    process_directory_no_auto_rotate
)

process_directory_no_auto_rotate(image_path)
# Out:
# [UC1986516_01.jpeg] Original size: (800, 603)
# [UC1986516_01.jpeg] No resize needed.
# [UC1986516_01.jpeg] Saved corrected image to /Users/danielleward/Downloads/images/UC1986516_01.jpeg
# [UC2032274.jpeg] Original size: (800, 368)
# [UC2032274.jpeg] No resize needed.
# [UC2032274.jpeg] Saved corrected image to /Users/danielleward/Downloads/images/UC2032274.jpeg
# [UC1577131.jpeg] Original size: (800, 403)
# [UC1577131.jpeg] No resize needed.
# [UC1577131.jpeg] Saved corrected image to /Users/danielleward/Downloads/images/UC1577131.jpeg
# [UC1141906_2.jpeg] Original size: (666, 999)
# [UC1141906_2.jpeg] No resize needed.
# [UC1141906_2.jpeg] Saved corrected image to /Users/danielleward/Downloads/images/UC1141906_2.jpeg
# [UC1998090.jpeg] Original size: (800, 409)
# [UC1998090.jpeg] No resize needed.
# [UC1998090.jpeg] Saved corrected image to /Users/danielleward/Downloads/images/UC1998090.jpeg
# [UC43241.jpeg] Original size: (800, 383)
# [UC43241.jpeg] No resize needed.
# [UC43241.jpeg] Saved corrected image to /Users/danielleward/Downloads/images/UC43241.jpeg
# [UC1901935.jpeg] Original size: (800, 300)
# [UC1901935.jpeg] No resize needed.
# [UC1901935.jpeg] Saved corrected image to /Users/danielleward/Downloads/images/UC1901935.jpeg
# [UC205360_01.jpeg] Original size: (800, 359)
# [UC205360_01.jpeg] No resize needed.
# [UC205360_01.jpeg] Saved corrected image to /Users/danielleward/Downloads/images/UC205360_01.jpeg
# [UC1901189.jpeg] Original size: (800, 423)
# [UC1901189.jpeg] No resize needed.
# [UC1901189.jpeg] Saved corrected image to /Users/danielleward/Downloads/images/UC1901189.jpeg
# [UC1726980.jpeg] Original size: (800, 550)
# [UC1726980.jpeg] No resize needed.
# [UC1726980.jpeg] Saved corrected image to /Users/danielleward/Downloads/images/UC1726980.jpeg
# [UC1067286.jpeg] Original size: (800, 553)
# [UC1067286.jpeg] No resize needed.
# [UC1067286.jpeg] Saved corrected image to /Users/danielleward/Downloads/images/UC1067286.jpeg
# [UC1938532.jpeg] Original size: (800, 853)
# [UC1938532.jpeg] No resize needed.
# [UC1938532.jpeg] Saved corrected image to /Users/danielleward/Downloads/images/UC1938532.jpeg
# [UC1714301.jpeg] Original size: (800, 427)
# [UC1714301.jpeg] No resize needed.
# [UC1714301.jpeg] Saved corrected image to /Users/danielleward/Downloads/images/UC1714301.jpeg
# [UC2002927.jpeg] Original size: (800, 501)
# [UC2002927.jpeg] No resize needed.
# [UC2002927.jpeg] Saved corrected image to /Users/danielleward/Downloads/images/UC2002927.jpeg
# [UC1475148.jpeg] Original size: (800, 440)
# [UC1475148.jpeg] No resize needed.
# [UC1475148.jpeg] Saved corrected image to /Users/danielleward/Downloads/images/UC1475148.jpeg

# %%
"""
Step 2: Calling the OCR AI model.
This step will call OCR and save the output to .json files in the tmp/ directory.

It will then build specimen labels based on the OCR output.
You do NOT need to edit this section.
"""

import json
import sys
import os
from herbarium_processor.core.ocr.ocr_client import OcrClient

ocr = OcrClient()

if image_path:
  for filename in os.listdir(image_path):
    path = os.path.join(image_path, filename)
    if filename.lower().endswith(".jpg") or filename.lower().endswith(".jpeg"):
      print(f"Processing {path}")
      ocr.extract_text_json(path)
# Out:
# Processing /Users/danielleward/Downloads/images/UC1986516_01.jpeg
# Saved visualized image with bounding boxes and sources to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_bounding_UC1986516_01.jpg
# Processing /Users/danielleward/Downloads/images/UC2032274.jpeg
# Saved visualized image with bounding boxes and sources to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_bounding_UC2032274.jpg
# Processing /Users/danielleward/Downloads/images/UC1577131.jpeg
# Saved visualized image with bounding boxes and sources to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_bounding_UC1577131.jpg
# Processing /Users/danielleward/Downloads/images/UC1141906_2.jpeg
# Saved visualized image with bounding boxes and sources to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_bounding_UC1141906_2.jpg
# Processing /Users/danielleward/Downloads/images/UC1998090.jpeg
# Saved visualized image with bounding boxes and sources to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_bounding_UC1998090.jpg
# Processing /Users/danielleward/Downloads/images/UC43241.jpeg
# Saved visualized image with bounding boxes and sources to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_bounding_UC43241.jpg
# Processing /Users/danielleward/Downloads/images/UC1901935.jpeg
# Saved visualized image with bounding boxes and sources to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_bounding_UC1901935.jpg
# Processing /Users/danielleward/Downloads/images/UC205360_01.jpeg
# Saved visualized image with bounding boxes and sources to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_bounding_UC205360_01.jpg
# Processing /Users/danielleward/Downloads/images/UC1901189.jpeg
# Saved visualized image with bounding boxes and sources to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_bounding_UC1901189.jpg
# Processing /Users/danielleward/Downloads/images/UC1726980.jpeg
# Saved visualized image with bounding boxes and sources to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_bounding_UC1726980.jpg
# Processing /Users/danielleward/Downloads/images/UC1067286.jpeg
# Saved visualized image with bounding boxes and sources to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_bounding_UC1067286.jpg
# Processing /Users/danielleward/Downloads/images/UC1938532.jpeg
# Saved visualized image with bounding boxes and sources to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_bounding_UC1938532.jpg
# Processing /Users/danielleward/Downloads/images/UC1714301.jpeg
# Saved visualized image with bounding boxes and sources to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_bounding_UC1714301.jpg
# Processing /Users/danielleward/Downloads/images/UC2002927.jpeg
# Saved visualized image with bounding boxes and sources to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_bounding_UC2002927.jpg
# Processing /Users/danielleward/Downloads/images/UC1475148.jpeg
# Saved visualized image with bounding boxes and sources to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_bounding_UC1475148.jpg

# %%
"""
Step 3: Building the samples for the prompt based on the OCR output.

This section will automatically generate the list of specimen labels
based on the sampled paths defined above.

You do NOT need to edit this section.
"""

from herbarium_processor.core.types.specimen_label import SpecimenLabel
from pathlib import Path

target_examples = []

if image_path:
  for filename in os.listdir(image_path):
    path = Path(os.path.join(image_path, filename))
    label = SpecimenLabel(
            id=path.stem,
            img_path=str(path),
            ocr_path=f"tmp/ocr_ai_input_{path.stem}.json"
        )
    target_examples.append(label)
    print("Saving specimen label with the following info:" + str(label))
# Out:
# Saving specimen label with the following info:SpecimenLabel(id='UC1986516_01', img_path=PosixPath('/Users/danielleward/Downloads/images/UC1986516_01.jpeg'), ocr_path=PosixPath('/Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_ai_input_UC1986516_01.json'))
# Saving specimen label with the following info:SpecimenLabel(id='UC2032274', img_path=PosixPath('/Users/danielleward/Downloads/images/UC2032274.jpeg'), ocr_path=PosixPath('/Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_ai_input_UC2032274.json'))
# Saving specimen label with the following info:SpecimenLabel(id='UC1577131', img_path=PosixPath('/Users/danielleward/Downloads/images/UC1577131.jpeg'), ocr_path=PosixPath('/Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_ai_input_UC1577131.json'))
# Saving specimen label with the following info:SpecimenLabel(id='UC1141906_2', img_path=PosixPath('/Users/danielleward/Downloads/images/UC1141906_2.jpeg'), ocr_path=PosixPath('/Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_ai_input_UC1141906_2.json'))
# Saving specimen label with the following info:SpecimenLabel(id='UC1998090', img_path=PosixPath('/Users/danielleward/Downloads/images/UC1998090.jpeg'), ocr_path=PosixPath('/Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_ai_input_UC1998090.json'))
# Saving specimen label with the following info:SpecimenLabel(id='UC43241', img_path=PosixPath('/Users/danielleward/Downloads/images/UC43241.jpeg'), ocr_path=PosixPath('/Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_ai_input_UC43241.json'))
# Saving specimen label with the following info:SpecimenLabel(id='UC1901935', img_path=PosixPath('/Users/danielleward/Downloads/images/UC1901935.jpeg'), ocr_path=PosixPath('/Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_ai_input_UC1901935.json'))
# Saving specimen label with the following info:SpecimenLabel(id='UC205360_01', img_path=PosixPath('/Users/danielleward/Downloads/images/UC205360_01.jpeg'), ocr_path=PosixPath('/Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_ai_input_UC205360_01.json'))
# Saving specimen label with the following info:SpecimenLabel(id='UC1901189', img_path=PosixPath('/Users/danielleward/Downloads/images/UC1901189.jpeg'), ocr_path=PosixPath('/Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_ai_input_UC1901189.json'))
# Saving specimen label with the following info:SpecimenLabel(id='UC1726980', img_path=PosixPath('/Users/danielleward/Downloads/images/UC1726980.jpeg'), ocr_path=PosixPath('/Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_ai_input_UC1726980.json'))
# Saving specimen label with the following info:SpecimenLabel(id='UC1067286', img_path=PosixPath('/Users/danielleward/Downloads/images/UC1067286.jpeg'), ocr_path=PosixPath('/Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_ai_input_UC1067286.json'))
# Saving specimen label with the following info:SpecimenLabel(id='UC1938532', img_path=PosixPath('/Users/danielleward/Downloads/images/UC1938532.jpeg'), ocr_path=PosixPath('/Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_ai_input_UC1938532.json'))
# Saving specimen label with the following info:SpecimenLabel(id='UC1714301', img_path=PosixPath('/Users/danielleward/Downloads/images/UC1714301.jpeg'), ocr_path=PosixPath('/Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_ai_input_UC1714301.json'))
# Saving specimen label with the following info:SpecimenLabel(id='UC2002927', img_path=PosixPath('/Users/danielleward/Downloads/images/UC2002927.jpeg'), ocr_path=PosixPath('/Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_ai_input_UC2002927.json'))
# Saving specimen label with the following info:SpecimenLabel(id='UC1475148', img_path=PosixPath('/Users/danielleward/Downloads/images/UC1475148.jpeg'), ocr_path=PosixPath('/Users/danielleward/Documents/Projects/herbarium-processor/tmp/ocr_ai_input_UC1475148.json'))

# %%
"""
Step 4: Calling the AI model

You do NOT need to edit this section.

Note to Danielle: If DS_Store files are present, run this in the terminal /Users/danielleward/Documents/Projects/herbarium-processor -name ".DS_Store" -type f -delete and find ~/Downloads/images -name '.DS_Store' -type f -delete
"""

from herbarium_processor.core.inference.label_extraction_batch_runner import LabelExtractionBatchRunner

runner = LabelExtractionBatchRunner(
    output_csv_path=output_csv_path,
    system_instructions_path=system_instructions_path,
    prompt_builder=prompt_builder,
    targets=target_examples
)
runner.run()
# Out:
# Running classification in parallel...
# Processing image: /Users/danielleward/Downloads/images/UC1986516_01.jpeg
# Processing image: /Users/danielleward/Downloads/images/UC2032274.jpeg
# Processing image: /Users/danielleward/Downloads/images/UC1577131.jpeg
# Processing image: /Users/danielleward/Downloads/images/UC1141906_2.jpeg
# Processing image: /Users/danielleward/Downloads/images/UC1998090.jpeg
# Processing image: /Users/danielleward/Downloads/images/UC43241.jpeg
# Processing image: /Users/danielleward/Downloads/images/UC1901935.jpeg
# Processing image: /Users/danielleward/Downloads/images/UC205360_01.jpeg
# Processing image: /Users/danielleward/Downloads/images/UC1901189.jpeg
# Processing image: /Users/danielleward/Downloads/images/UC1726980.jpeg
# Processing image: /Users/danielleward/Downloads/images/UC1067286.jpeg
# Processing image: /Users/danielleward/Downloads/images/UC1938532.jpeg
# Saved output to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/processed_output_1753993087_UC2032274.json
# Done classifying image: /Users/danielleward/Downloads/images/UC2032274.jpeg
# Processing image: /Users/danielleward/Downloads/images/UC1714301.jpeg
# Saved output to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/processed_output_1753993087_UC1726980.json
# Done classifying image: /Users/danielleward/Downloads/images/UC1726980.jpeg
# Processing image: /Users/danielleward/Downloads/images/UC2002927.jpeg
# Saved output to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/processed_output_1753993087_UC1901189.json
# Done classifying image: /Users/danielleward/Downloads/images/UC1901189.jpeg
# Processing image: /Users/danielleward/Downloads/images/UC1475148.jpeg
# Saved output to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/processed_output_1753993087_UC205360_01.json
# Done classifying image: /Users/danielleward/Downloads/images/UC205360_01.jpeg
# Saved output to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/processed_output_1753993087_UC1986516_01.json
# Done classifying image: /Users/danielleward/Downloads/images/UC1986516_01.jpeg
# Saved output to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/processed_output_1753993087_UC1938532.json
# Done classifying image: /Users/danielleward/Downloads/images/UC1938532.jpeg
# Saved output to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/processed_output_1753993087_UC1577131.json
# Done classifying image: /Users/danielleward/Downloads/images/UC1577131.jpeg
# Saved output to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/processed_output_1753993087_UC1067286.json
# Done classifying image: /Users/danielleward/Downloads/images/UC1067286.jpeg
# Saved output to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/processed_output_1753993087_UC43241.json
# Done classifying image: /Users/danielleward/Downloads/images/UC43241.jpeg
# Saved output to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/processed_output_1753993087_UC1475148.json
# Done classifying image: /Users/danielleward/Downloads/images/UC1475148.jpeg
# Saved output to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/processed_output_1753993087_UC1901935.json
# Done classifying image: /Users/danielleward/Downloads/images/UC1901935.jpeg
# Saved output to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/processed_output_1753993087_UC1141906_2.json
# Done classifying image: /Users/danielleward/Downloads/images/UC1141906_2.jpeg
# Saved output to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/processed_output_1753993087_UC2002927.json
# Done classifying image: /Users/danielleward/Downloads/images/UC2002927.jpeg
# Saved output to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/processed_output_1753993087_UC1714301.json
# Done classifying image: /Users/danielleward/Downloads/images/UC1714301.jpeg
# Saved output to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/processed_output_1753993087_UC1998090.json
# Done classifying image: /Users/danielleward/Downloads/images/UC1998090.jpeg
# Saved CSV to /Users/danielleward/Documents/Projects/herbarium-processor/tmp/an_output.csv

# %%
""" STep 5: Generating comparison report

You do NOT need to edit this section.
"""

from herbarium_processor.core.analysis.html_report_generator import HTMLReportGenerator

canonical_csv_path = "/Users/danielleward/Downloads/random_sample.csv"
html_output_path  = "tmp/html_report.html"

reporter = HTMLReportGenerator(
    canonical_csv_path=canonical_csv_path,
    test_csv_path=output_csv_path,
    html_output_path=html_output_path,
    prompt_builder=prompt_builder,
    system_instructions_path=system_instructions_path
)

reporter.run_all()
# Out:
# 🧠 Model Accuracy Summary
# ✅ Total Accuracy Across All Fields: 70.5%
#
# 📊 Per-Field Accuracy:
#                                     accuracy
# label_header                             0.7
# scientific_name                          0.3
# field_collection_location_verbatim       0.1
# county                                   0.6
# state                                    0.5
# country                                  1.0
# verbatim_latitude                        0.8
# verbatim_longitude                       0.8
# elevation                                0.4
# habitat_information                      0.5
# field_collection_date                    0.0
# comment                                  0.8
# field_collectors                         0.8
# field_collection_number                  1.0
# identifier                               0.9
# identification_date                      0.8
# exsiccatae                               0.9
# associated_taxa                          0.9
# old_scientific_name                      1.0
# old_identifier                           1.0
# old_identification_date                  1.0
# <button onclick="toggleSampleDiffView()">Toggle Diff View</button>
# <script>
# function toggleSampleDiffView() {
#     const origTables = document.querySelectorAll('.sample-orig-table');
#     const diffTables = document.querySelectorAll('.sample-diff-table');
#     for (let i = 0; i < origTables.length; i++) {
#         if (origTables[i].style.display === 'none') {
#             origTables[i].style.display = '';
#             diffTables[i].style.display = 'none';
#         } else {
#             origTables[i].style.display = 'none';
#             diffTables[i].style.display = '';
#         }
#     }
# }
# </script>
# <h4>❌ Sample Mismatches in Column: label_header</h4><table class='sample-orig-table' border='1' style='border-collapse:collapse;font-family:sans-serif;font-size:14px;'><tr><th style='padding:4px;'>ID</th><th style='padding:4px;'>Test Value</th><th style='padding:4px;'>Canonical Value</th></tr><tr><td style='padding:4px;'>UC1026554</td><td style='padding:4px;'></td><td style='padding:4px;'>K. H. et F. RECHINGER, ITER IRANICUM II., 1948</td></tr><tr><td style='padding:4px;'>UC1631606</td><td style='padding:4px;'>Bryophytes of Australia</td><td style='padding:4px;'>BRYOPHYTES OF AUSTRALIA STATE OF Queensland</td></tr><tr><td style='padding:4px;'>UC1920256</td><td style='padding:4px;'>Bryophytes of Iran</td><td style='padding:4px;'>Bryophytes of Iran Golestan Province</td></tr></table><table class='sample-diff-table' border='1' style='border-collapse:collapse;font-family:sans-serif;font-size:14px; display:none;'><tr><th style='padding:4px;'>ID</th><th style='padding:4px;' colspan='2'>Diff (test vs canonical)</th></tr><tr><td style='padding:4px;'>UC1026554</td><td style='padding:4px;' colspan='2'><span class='arrow-view' style='display:none'><br><small><i>→ K. H. et F. RECHINGER, ITER IRANICUM II., 1948</i></small></span><span class='diff-view'><span style="background-color:#ccffcc">K</span><span style="background-color:#ccffcc">.</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">H</span><span style="background-color:#ccffcc">.</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">e</span><span style="background-color:#ccffcc">t</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">F</span><span style="background-color:#ccffcc">.</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">R</span><span style="background-color:#ccffcc">E</span><span style="background-color:#ccffcc">C</span><span style="background-color:#ccffcc">H</span><span style="background-color:#ccffcc">I</span><span style="background-color:#ccffcc">N</span><span style="background-color:#ccffcc">G</span><span style="background-color:#ccffcc">E</span><span style="background-color:#ccffcc">R</span><span style="background-color:#ccffcc">,</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">I</span><span style="background-color:#ccffcc">T</span><span style="background-color:#ccffcc">E</span><span style="background-color:#ccffcc">R</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">I</span><span style="background-color:#ccffcc">R</span><span style="background-color:#ccffcc">A</span><span style="background-color:#ccffcc">N</span><span style="background-color:#ccffcc">I</span><span style="background-color:#ccffcc">C</span><span style="background-color:#ccffcc">U</span><span style="background-color:#ccffcc">M</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">I</span><span style="background-color:#ccffcc">I</span><span style="background-color:#ccffcc">.</span><span style="background-color:#ccffcc">,</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">1</span><span style="background-color:#ccffcc">9</span><span style="background-color:#ccffcc">4</span><span style="background-color:#ccffcc">8</span><br><small><i>→ K. H. et F. RECHINGER, ITER IRANICUM II., 1948</i></small></span></td></tr><tr><td style='padding:4px;'>UC1631606</td><td style='padding:4px;' colspan='2'><span class='arrow-view' style='display:none'>Bryophytes of Australia<br><small><i>→ BRYOPHYTES OF AUSTRALIA STATE OF Queensland</i></small></span><span class='diff-view'>B<span style="background-color:#ffcccc">r</span><span style="background-color:#ffcccc">y</span><span style="background-color:#ffcccc">o</span><span style="background-color:#ffcccc">p</span><span style="background-color:#ffcccc">h</span> ...
# <button onclick="toggleDiffView()">Toggle Diff View</button>
# <script>
# function toggleDiffView() {
#     const arrow = document.querySelectorAll('.arrow-view');
#     const diff = document.querySelectorAll('.diff-view');
#     for (let i = 0; i < arrow.length; i++) {
#         if (arrow[i].style.display === 'none') {
#             arrow[i].style.display = 'inline';
#             diff[i].style.display = 'none';
#         } else {
#             arrow[i].style.display = 'none';
#             diff[i].style.display = 'inline';
#         }
#     }
# }
# </script>
# <table border="1" style="border-collapse: collapse; font-family: sans-serif; font-size: 14px;"><tr><th style="padding: 6px;">ID</th><th style="padding: 6px;">label_header</th><th style="padding: 6px;">scientific_name</th><th style="padding: 6px;">field_collection_location_verbatim</th><th style="padding: 6px;">county</th><th style="padding: 6px;">state</th><th style="padding: 6px;">country</th><th style="padding: 6px;">verbatim_latitude</th><th style="padding: 6px;">verbatim_longitude</th><th style="padding: 6px;">elevation</th><th style="padding: 6px;">habitat_information</th><th style="padding: 6px;">field_collection_date</th><th style="padding: 6px;">comment</th><th style="padding: 6px;">field_collectors</th><th style="padding: 6px;">field_collection_number</th><th style="padding: 6px;">identifier</th><th style="padding: 6px;">identification_date</th><th style="padding: 6px;">exsiccatae</th><th style="padding: 6px;">associated_taxa</th><th style="padding: 6px;">old_scientific_name</th><th style="padding: 6px;">old_identifier</th><th style="padding: 6px;">old_identification_date</th></tr><tr><td style="padding: 4px;"><b>UC1026554</b><br><a href="https://lichenportal.org/portal/collections/individual/index.php?occid=UC1026554" target="_blank">🔗</a></td><td style="background-color: #ff0080; color: #000; font-weight: bold; padding: 4px;"><span class='arrow-view'><br><small><i>→ K. H. et F. RECHINGER, ITER IRANICUM II., 1948</i></small></span><span class='diff-view' style='display:none'><span style="background-color:#ccffcc">K</span><span style="background-color:#ccffcc">.</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">H</span><span style="background-color:#ccffcc">.</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">e</span><span style="background-color:#ccffcc">t</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">F</span><span style="background-color:#ccffcc">.</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">R</span><span style="background-color:#ccffcc">E</span><span style="background-color:#ccffcc">C</span><span style="background-color:#ccffcc">H</span><span style="background-color:#ccffcc">I</span><span style="background-color:#ccffcc">N</span><span style="background-color:#ccffcc">G</span><span style="background-color:#ccffcc">E</span><span style="background-color:#ccffcc">R</span><span style="background-color:#ccffcc">,</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">I</span><span style="background-color:#ccffcc">T</span><span style="background-color:#ccffcc">E</span><span style="background-color:#ccffcc">R</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">I</span><span style="background-color:#ccffcc">R</span><span style="background-color:#ccffcc">A</span><span style="background-color:#ccffcc">N</span><span style="background-color:#ccffcc">I</span><span style="background-color:#ccffcc">C</span><span style="background-color:#ccffcc">U</span><span style="background-color:#ccffcc">M</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">I</span><span style="background-color:#ccffcc">I</span><span style="background-color:#ccffcc">.</span><span style="background-color:#ccffcc">,</span><span style="background-color:#ccffcc"> </span><span style="background-color:#ccffcc">1</span><span style="background-color:#ccffcc">9</span><span style="background-color:#ccffcc">4</span><span style="background-color:#ccffcc">8</span><br><small><i>→ K. H. et F. RECHINGER, ITER IRANICUM II., 1948</i></small></span></td><td style="background-color: #fff380; color: #000; font-weight: bold; padding: 4px;"><span class='arrow-view'>Hypnum Vaucheri Lesq.<br><small><i>→ Hypnum vaucheri Lesq.</i></small></span><span class='diff-view' style='display:none'>Hypnum <sp ...
