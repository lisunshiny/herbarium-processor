# %%
"""
Herbarium Processor Notebook
========================

This notebook is designed to process herbarium specimen images and generate labels using a prompt-based approach.
It includes steps for image processing, prompt configuration, and generating specimen labels.
It is structured to be run in a Jupyter notebook environment.

Configuration: select what images to sample from.

You should edit this section each time you run the code to:
  * select the images you want to process
  * set the path to the output CSV file.
"""

from utils.notebook_setup import setup_project

setup_project()

image_path = "data/img/bucket"
output_csv_path = "tmp/an_output.csv"
# Out:
# Notebook root set to /Users/liann/workspace/herbarium-processor

# %%
"""
Configuration: setting up the prompts and system instructions for Gemini inference.

You do NOT need to edit this section.
"""

from herbarium_processor.core.inference.prompt_factory import (
    create_prompt_builder_from_yaml,
)

system_instructions_path = "prompts/ocr_system_instructions_no_citations.md"
prompt_builder = create_prompt_builder_from_yaml("prompts/configs/default_prompt.yaml")

print("Prompt:")
print(prompt_builder.generate_debug_prompt())
# Out:
# Prompt:
# You are an AI assistant trained to extract structured data from herbarium specimen label images.
#
# You will be shown 3 label images and corresponding OCR blocks as examples. These examples include the correct structured JSON output. After that, you will be shown a fourth image (with OCR blocks) that you must process.
#
# Use both the image and the OCR output to extract only the following 21 fields as a valid JSON object using `snake_case` keys:
#
# * `label_header`
# * `scientific_name`
# * `field_collection_location_verbatim`
# * `county`
# * `state`
# * `country`
# * `verbatim_latitude`
# * `verbatim_longitude`
# * `elevation`
# * `habitat_information`
# * `field_collection_date`
# * `comment`
# * `field_collectors`
# * `field_collection_number`
# * `identifier`
# * `identification_date`
# * `exsiccatae`
# * `associated_taxa`
# * `old_scientific_name`
# * `old_identifier`
# * `old_identification_date`
#
#
# Return `null` for any field that is not clearly present or legible. Do **not** infer or fabricate any information. Do **not** return extra fields.
#
# ---
# **Example 1**
#
# Image:
# <|image_0|>
#
# OCR Output:
# ```json
# [
#   {
#     "average_confidence": 0.9735246280000001,
#     "bounding_box": [
#       {
#         "x": 229,
#         "y": 175
#       },
#       {
#         "x": 839,
#         "y": 175
#       },
#       {
#         "x": 839,
#         "y": 211
#       },
#       {
#         "x": 229,
#         "y": 211
#       }
#     ],
#     "id": "1.1.1",
#     "text": "F. RENAULD \u0026 J. CARDOT"
#   },
#   {
#     "average_confidence": 0.9616529533333332,
#     "bounding_box": [
#       {
#         "x": 175,
#         "y": 237
#       },
#       {
#         "x": 890,
#         "y": 237
#       },
#       {
#         "x": 890,
#         "y": 287
#       },
#       {
#         "x": 175,
#         "y": 287
#       }
#     ],
#     "id": "1.1.2",
#     "text": "Musci europ\u00e6i exsiccati"
#   },
#   {
#     "average_confidence": 0.5832276,
#     "bounding_box": [
#       {
#         "x": 531,
#         "y": 301
#       },
#       {
#         "x": 597,
#         "y": 301
#       },
#       {
#         "x": 597,
#         "y": 315
#       },
#       {
#         "x": 531,
#         "y": 315
#       }
#     ],
#     "id": "1.1.3",
#     "text": "303"
#   },
#   {
#     "average_confidence": 0.831805994,
#     "bounding_box": [
#       {
#         "x": 151,
#         "y": 360
#       },
#       {
#         "x": 920,
#         "y": 360
#       },
#       {
#         "x": 920,
#         "y": 445
#       },
#       {
#         "x": 151,
#         "y": 445
#       }
#     ],
#     "id": "1.1.4",
#     "text": "N\u00ba30 . Fontinalis arvernica Ren-"
#   },
#   {
#     "average_confidence": 0.9345777649999999,
#     "bounding_box": [
#       {
#         "x": 86,
#         "y": 470
#       },
#       {
#         "x": 888,
#         "y": 470
#       },
#       {
#         "x": 888,
#         "y": 549
#       },
#       {
#         "x": 86,
#         "y": 549
#       }
#     ],
#     "id": "1.1.5",
#     "text": "In aquis profundis lacus Pavin Arverniae"
#   },
#   {
#     "average_confidence": 0.828987095,
#     "bounding_box": [
#       {
#         "x": 460,
#         "y": 553
#       },
#       {
#         "x": 873,
#         "y": 553
#       },
#       {
#         "x": 873,
#         "y": 642
#       },
#       {
#         "x": 460,
#         "y": 642
#       }
#     ],
#     "id": "1.1.6",
#     "text": "Leg . F. Renauld"
#   },
#   {
#     "average_confidence": 0.6125826249999999,
#     "bounding_box": [
#       {
#         "x": 69,
#         "y": 740
#       },
#       {
#         "x": 722,
#         "y": 740
#       },
#       {
#         "x": 722,
#         "y": 844
#       },
#       {
#         "x": 69,
#         "y": 844
#       }
#     ],
#     "id": "1.1.7",
#     "text": "Fontinalis autifystica"
#   },
#   {
#     "average_confidence": 0.44124288333333334,
#     "bounding_box": [
#       {
#         "x": 736,
#         "y": 783
#       },
#       {
#         "x": 856,
#         "y": 783
#       },
#       {
#         "x": 856,
#         "y": 852
#       },
#       {
#         "x": 736,
#         "y": 852
#       }
#     ],
#     "id": "1.1.8",
#     "text": "[ . ]"
#   },
#   {
#     "average_confidence": 0.802025325,
#     "bounding_box": [
#       {
#         "x": 71,
#         "y": 819
#       },
#       {
#         "x": 246,
#         "y": 819
#       },
#       {
#         "x": 246,
#         "y": 859
#       },
#       {
#         "x": 71,
#         "y": 859
#       }
#     ],
#     "id": "1.1.9",
#     "text": "Hedw ."
#   },
#   {
#     "average_confidence": 0.9705295266666667,
#     "bounding_box": [
#       {
#         "x": 98,
#         "y": 877
#       },
#       {
#         "x": 880,
#         "y": 877
#       },
#       {
#         "x": 880,
#         "y": 915
#       },
#       {
#         "x": 98,
#         "y": 915
#       }
#     ],
#     "id": "1.1.10",
#     "text": "Determined by Winona H. Welch 8-14-1945"
#   },
#   {
#     "average_confidence": 0.67041407,
#     "bounding_box": [
#       {
#         "x": 70,
#         "y": 915
#       },
#       {
#         "x": 142,
#         "y": 915
#       },
#       {
#         "x": 142,
#         "y": 938
#       },
#       {
#         "x": 70,
#         "y": 938
#       }
#     ],
#     "id": "1.1.11",
#     "text": "30 ."
#   }
# ]
# ```
#
# Correct Output:
# ```json
# {
#   "associated_taxa": null,
#   "comment": "In aquis profundis",
#   "country": "France",
#   "county": null,
#   "elevation": null,
#   "exsiccatae": "Musci europ\u00e6i exsiccati",
#   "field_collection_date": null,
#   "field_collection_location_verbatim": "lacus Pavin Arverniae",
#   "field_collection_number": "30",
#   "field_collectors": "[\u0027F. Renauld\u0027]",
#   "habitat_information": null,
#   "identification_date": "14-Aug-45",
#   "identifier": "Winona H. Welch",
#   "label_header": "F. RENAULD \u0026 J. CARDOT",
#   "old_identification_date": null,
#   "old_identifier": "Ren.",
#   "old_scientific_name": "Fontinalis avernica",
#   "scientific_name": "Fontinalis antipyretica Hedw.",
#   "state": null,
#   "verbatim_latitude": null,
#   "verbatim_longitude": null
# }
# ```
#
# ---
# **Example 2**
#
# Image:
# <|image_1|>
#
# OCR Output:
# ```json
# [
#   {
#     "average_confidence": 0.984642865,
#     "bounding_box": [
#       {
#         "x": 300,
#         "y": 94
#       },
#       {
#         "x": 606,
#         "y": 94
#       },
#       {
#         "x": 606,
#         "y": 127
#       },
#       {
#         "x": 300,
#         "y": 127
#       }
#     ],
#     "id": "1.1.1",
#     "text": "MUSCI JAPONICI"
#   },
#   {
#     "average_confidence": 0.9760597423076922,
#     "bounding_box": [
#       {
#         "x": 76,
#         "y": 158
#       },
#       {
#         "x": 828,
#         "y": 158
#       },
#       {
#         "x": 828,
#         "y": 187
#       },
#       {
#         "x": 76,
#         "y": 187
#       }
#     ],
#     "id": "1.1.2",
#     "text": "Ser . 9 ( 1955 ) Edited by A. Noguchi \u0026 S. Hattori"
#   },
#   {
#     "average_confidence": 0.9795091333333333,
#     "bounding_box": [
#       {
#         "x": 74,
#         "y": 248
#       },
#       {
#         "x": 434,
#         "y": 248
#       },
#       {
#         "x": 434,
#         "y": 274
#       },
#       {
#         "x": 74,
#         "y": 274
#       }
#     ],
#     "id": "1.1.3",
#     "text": "420. Fontinalis antipyretica"
#   },
#   {
#     "average_confidence": 0.971444046,
#     "bounding_box": [
#       {
#         "x": 446,
#         "y": 250
#       },
#       {
#         "x": 582,
#         "y": 250
#       },
#       {
#         "x": 582,
#         "y": 274
#       },
#       {
#         "x": 446,
#         "y": 274
#       }
#     ],
#     "id": "1.1.4",
#     "text": "( L. ) Hedw ."
#   },
#   {
#     "average_confidence": 0.9811021606666667,
#     "bounding_box": [
#       {
#         "x": 76,
#         "y": 365
#       },
#       {
#         "x": 830,
#         "y": 365
#       },
#       {
#         "x": 830,
#         "y": 393
#       },
#       {
#         "x": 76,
#         "y": 393
#       }
#     ],
#     "id": "1.1.5",
#     "text": "Rocks submerged in stream , ca. 1500 m . alt . , near Azumi ,"
#   },
#   {
#     "average_confidence": 0.985448875,
#     "bounding_box": [
#       {
#         "x": 76,
#         "y": 398
#       },
#       {
#         "x": 316,
#         "y": 398
#       },
#       {
#         "x": 316,
#         "y": 424
#       },
#       {
#         "x": 76,
#         "y": 424
#       }
#     ],
#     "id": "1.1.6",
#     "text": "Nagano Prefecture"
#   },
#   {
#     "average_confidence": 0.7980332,
#     "bounding_box": [
#       {
#         "x": 801,
#         "y": 428
#       },
#       {
#         "x": 829,
#         "y": 428
#       },
#       {
#         "x": 829,
#         "y": 453
#       },
#       {
#         "x": 801,
#         "y": 453
#       }
#     ],
#     "id": "1.1.7",
#     "text": "OF"
#   },
#   {
#     "average_confidence": 0.9351292653333334,
#     "bounding_box": [
#       {
#         "x": 74,
#         "y": 428
#       },
#       {
#         "x": 860,
#         "y": 428
#       },
#       {
#         "x": 860,
#         "y": 471
#       },
#       {
#         "x": 74,
#         "y": 471
#       }
#     ],
#     "id": "1.1.8",
#     "text": "Coll . U. Mizushima ( Mrs. ) , September 29 , 1954 HERBARIUM OF THE"
#   },
#   {
#     "average_confidence": 0.68084073,
#     "bounding_box": [
#       {
#         "x": 750,
#         "y": 462
#       },
#       {
#         "x": 828,
#         "y": 462
#       },
#       {
#         "x": 828,
#         "y": 500
#       },
#       {
#         "x": 750,
#         "y": 500
#       }
#     ],
#     "id": "1.1.9",
#     "text": "UC"
#   },
#   {
#     "average_confidence": 0.9760237975,
#     "bounding_box": [
#       {
#         "x": 74,
#         "y": 479
#       },
#       {
#         "x": 290,
#         "y": 479
#       },
#       {
#         "x": 290,
#         "y": 506
#       },
#       {
#         "x": 74,
#         "y": 506
#       }
#     ],
#     "id": "1.1.10",
#     "text": "Det . A. Noguchi"
#   },
#   {
#     "average_confidence": 0.8101489133333333,
#     "bounding_box": [
#       {
#         "x": 698,
#         "y": 490
#       },
#       {
#         "x": 860,
#         "y": 490
#       },
#       {
#         "x": 860,
#         "y": 534
#       },
#       {
#         "x": 698,
#         "y": 534
#       }
#     ],
#     "id": "1.1.11",
#     "text": "FIERSITY OF CALIFOR"
#   },
#   {
#     "average_confidence": 0.7194973,
#     "bounding_box": [
#       {
#         "x": 332,
#         "y": 566
#       },
#       {
#         "x": 444,
#         "y": 566
#       },
#       {
#         "x": 444,
#         "y": 676
#       },
#       {
#         "x": 332,
#         "y": 676
#       }
#     ],
#     "id": "1.1.12",
#     "text": "UNIVERS"
#   },
#   {
#     "average_confidence": 0.9516384499999999,
#     "bounding_box": [
#       {
#         "x": 392,
#         "y": 570
#       },
#       {
#         "x": 593,
#         "y": 570
#       },
#       {
#         "x": 593,
#         "y": 602
#       },
#       {
#         "x": 392,
#         "y": 602
#       }
#     ],
#     "id": "1.1.13",
#     "text": "M 207518"
#   },
#   {
#     "average_confidence": 0.8396531,
#     "bounding_box": [
#       {
#         "x": 536,
#         "y": 559
#       },
#       {
#         "x": 669,
#         "y": 559
#       },
#       {
#         "x": 669,
#         "y": 680
#       },
#       {
#         "x": 536,
#         "y": 680
#       }
#     ],
#     "id": "1.1.14",
#     "text": "CALIFORNIA"
#   },
#   {
#     "average_confidence": 0.9783724,
#     "bounding_box": [
#       {
#         "x": 486,
#         "y": 653
#       },
#       {
#         "x": 522,
#         "y": 653
#       },
#       {
#         "x": 522,
#         "y": 672
#       },
#       {
#         "x": 486,
#         "y": 672
#       }
#     ],
#     "id": "1.1.15",
#     "text": "OF"
#   }
# ]
# ```
#
# Correct Output:
# ```json
# {
#   "associated_taxa": null,
#   "comment": "Ser. 9 (1955) Edited by A. Noguchi \u0026 S. Hattori",
#   "country": "Japan",
#   "county": null,
#   "elevation": "ca. 1500 m.",
#   "exsiccatae": null,
#   "field_collection_date": "29-Sep-54",
#   "field_collection_location_verbatim": "near Azumi",
#   "field_collection_number": null,
#   "field_collectors": "[\u0027U. Mizushima (Mrs.)\u0027]",
#   "habitat_information": "Rocks submerged in stream",
#   "identification_date": null,
#   "identifier": "A. Noguchi",
#   "label_header": "MUSCI JAPONICI",
#   "old_identification_date": null,
#   "old_identifier": null,
#   "old_scientific_name": null,
#   "scientific_name": "Fontinalis antipyretica (L.) Hedw.",
#   "state": "Nagano Prefecture",
#   "verbatim_latitude": null,
#   "verbatim_longitude": null
# }
# ```
#
# ---
# **Example 3**
#
# Image:
# <|image_2|>
#
# OCR Output:
# ```json
# [
#   {
#     "average_confidence": 0.9877717,
#     "bounding_box": [
#       {
#         "x": 469,
#         "y": 38
#       },
#       {
#         "x": 630,
#         "y": 38
#       },
#       {
#         "x": 630,
#         "y": 62
#       },
#       {
#         "x": 469,
#         "y": 62
#       }
#     ],
#     "id": "1.1.1",
#     "text": "Duplicatum ex"
#   },
#   {
#     "average_confidence": 0.9869702433333334,
#     "bounding_box": [
#       {
#         "x": 344,
#         "y": 75
#       },
#       {
#         "x": 763,
#         "y": 75
#       },
#       {
#         "x": 763,
#         "y": 100
#       },
#       {
#         "x": 344,
#         "y": 100
#       }
#     ],
#     "id": "1.1.2",
#     "text": "CONSERVATORIO BOTANICO GENEVENSI"
#   },
#   {
#     "average_confidence": 0.99032766,
#     "bounding_box": [
#       {
#         "x": 493,
#         "y": 120
#       },
#       {
#         "x": 602,
#         "y": 120
#       },
#       {
#         "x": 602,
#         "y": 136
#       },
#       {
#         "x": 493,
#         "y": 136
#       }
#     ],
#     "id": "1.1.3",
#     "text": "HELVETIAE"
#   },
#   {
#     "average_confidence": 0.88217158,
#     "bounding_box": [
#       {
#         "x": 280,
#         "y": 168
#       },
#       {
#         "x": 490,
#         "y": 168
#       },
#       {
#         "x": 490,
#         "y": 192
#       },
#       {
#         "x": 280,
#         "y": 192
#       }
#     ],
#     "id": "1.1.4",
#     "text": "390 . Fontinalis"
#   },
#   {
#     "average_confidence": 0.9535369380000001,
#     "bounding_box": [
#       {
#         "x": 502,
#         "y": 171
#       },
#       {
#         "x": 796,
#         "y": 171
#       },
#       {
#         "x": 796,
#         "y": 199
#       },
#       {
#         "x": 502,
#         "y": 199
#       }
#     ],
#     "id": "1.1.5",
#     "text": "antipyretica L. ex Hedw ."
#   },
#   {
#     "average_confidence": 0.9365827622222223,
#     "bounding_box": [
#       {
#         "x": 202,
#         "y": 218
#       },
#       {
#         "x": 710,
#         "y": 218
#       },
#       {
#         "x": 710,
#         "y": 246
#       },
#       {
#         "x": 202,
#         "y": 246
#       }
#     ],
#     "id": "1.1.6",
#     "text": "Loc .: Suisse . Vaud . Commune de Chavannes"
#   },
#   {
#     "average_confidence": 0.9293862388888888,
#     "bounding_box": [
#       {
#         "x": 288,
#         "y": 230
#       },
#       {
#         "x": 844,
#         "y": 230
#       },
#       {
#         "x": 844,
#         "y": 274
#       },
#       {
#         "x": 288,
#         "y": 274
#       }
#     ],
#     "id": "1.1.7",
#     "text": "Cours de la Versoix ( rivi\u00e8re des Bois ."
#   },
#   {
#     "average_confidence": 0.9901602,
#     "bounding_box": [
#       {
#         "x": 638,
#         "y": 250
#       },
#       {
#         "x": 658,
#         "y": 250
#       },
#       {
#         "x": 658,
#         "y": 274
#       },
#       {
#         "x": 638,
#         "y": 274
#       }
#     ],
#     "id": "1.1.8",
#     "text": ") ."
#   },
#   {
#     "average_confidence": 0.8883680110000001,
#     "bounding_box": [
#       {
#         "x": 200,
#         "y": 272
#       },
#       {
#         "x": 846,
#         "y": 272
#       },
#       {
#         "x": 846,
#         "y": 303
#       },
#       {
#         "x": 200,
#         "y": 303
#       }
#     ],
#     "id": "1.1.9",
#     "text": "Leg . S. Vautier et J - D . Bersier"
#   },
#   {
#     "average_confidence": 0.9210517628571429,
#     "bounding_box": [
#       {
#         "x": 199,
#         "y": 296
#       },
#       {
#         "x": 734,
#         "y": 296
#       },
#       {
#         "x": 734,
#         "y": 326
#       },
#       {
#         "x": 199,
#         "y": 326
#       }
#     ],
#     "id": "1.1.10",
#     "text": "Date : 1 juin 1964 . Alt"
#   },
#   {
#     "average_confidence": 0.9414688275,
#     "bounding_box": [
#       {
#         "x": 736,
#         "y": 310
#       },
#       {
#         "x": 842,
#         "y": 310
#       },
#       {
#         "x": 842,
#         "y": 330
#       },
#       {
#         "x": 736,
#         "y": 330
#       }
#     ],
#     "id": "1.1.11",
#     "text": ". 464 m ."
#   },
#   {
#     "average_confidence": 0.960434021111111,
#     "bounding_box": [
#       {
#         "x": 199,
#         "y": 337
#       },
#       {
#         "x": 757,
#         "y": 337
#       },
#       {
#         "x": 757,
#         "y": 370
#       },
#       {
#         "x": 199,
#         "y": 370
#       }
#     ],
#     "id": "1.1.12",
#     "text": "Obs .: Sur les pierres submerg\u00e9es dans le lit"
#   },
#   {
#     "average_confidence": 0.9866670000000001,
#     "bounding_box": [
#       {
#         "x": 286,
#         "y": 350
#       },
#       {
#         "x": 832,
#         "y": 350
#       },
#       {
#         "x": 832,
#         "y": 388
#       },
#       {
#         "x": 286,
#         "y": 388
#       }
#     ],
#     "id": "1.1.13",
#     "text": "rivi\u00e8re de la"
#   },
#   {
#     "average_confidence": 0.9415124,
#     "bounding_box": [
#       {
#         "x": 374,
#         "y": 371
#       },
#       {
#         "x": 382,
#         "y": 371
#       },
#       {
#         "x": 382,
#         "y": 387
#       },
#       {
#         "x": 374,
#         "y": 387
#       }
#     ],
#     "id": "1.1.14",
#     "text": "."
#   },
#   {
#     "average_confidence": 0.9880059133333333,
#     "bounding_box": [
#       {
#         "x": 418,
#         "y": 564
#       },
#       {
#         "x": 610,
#         "y": 564
#       },
#       {
#         "x": 610,
#         "y": 616
#       },
#       {
#         "x": 418,
#         "y": 616
#       }
#     ],
#     "id": "1.1.15",
#     "text": "HERBARIUM OF THE"
#   },
#   {
#     "average_confidence": 0.7149779,
#     "bounding_box": [
#       {
#         "x": 386,
#         "y": 610
#       },
#       {
#         "x": 463,
#         "y": 610
#       },
#       {
#         "x": 463,
#         "y": 686
#       },
#       {
#         "x": 386,
#         "y": 686
#       }
#     ],
#     "id": "1.1.16",
#     "text": "CNIVER"
#   },
#   {
#     "average_confidence": 0.9897582,
#     "bounding_box": [
#       {
#         "x": 447,
#         "y": 610
#       },
#       {
#         "x": 581,
#         "y": 610
#       },
#       {
#         "x": 581,
#         "y": 644
#       },
#       {
#         "x": 447,
#         "y": 644
#       }
#     ],
#     "id": "1.1.17",
#     "text": "1318628"
#   }
# ]
# ```
#
# Correct Output:
# ```json
# {
#   "associated_taxa": null,
#   "comment": null,
#   "country": "Switzerland",
#   "county": null,
#   "elevation": "464 m.",
#   "exsiccatae": "Duplicatum ex CONSERVATORIO BOTANICO GENEVENSI HELVETIAE",
#   "field_collection_date": "1-Jun-64",
#   "field_collection_location_verbatim": "Vaud. Commune de Chavannes des Bois. Cours de la Versoix (rivi\u00e8re).",
#   "field_collection_number": "390",
#   "field_collectors": "[\u0027S. Vautier\u0027, \u0027J-D. Bersier\u0027]",
#   "habitat_information": "Sur les pierres submerg\u00e9es dans le lit de la rivi\u00e8re.",
#   "identification_date": "16-Aug-45",
#   "identifier": "Winona H. Welch",
#   "label_header": null,
#   "old_identification_date": null,
#   "old_identifier": null,
#   "old_scientific_name": null,
#   "scientific_name": "Fontinalis antipyretica L. ex Hedw.",
#   "state": "Vaud",
#   "verbatim_latitude": null,
#   "verbatim_longitude": null
# }
# ```
#
#
# ---
#
# **Now classify this image:**
#
# Image:
# <|image_3|>
#
# OCR Output:
# ```json
# {}
# ```
#
# Return your output as a single valid JSON object with **only the fields listed above**. Be precise. Do not guess unknown fields.

# %%
"""
Step 1: Image processing.

Take the .heic images from the phone and convert them to .jpg format.
This step also includes resizing the images to a standard size and doing any necessary preprocessing.

You do NOT need to edit this section.
"""

from herbarium_processor.core.image.image_utils import process_directory_no_auto_rotate

process_directory_no_auto_rotate(image_path)
# Out:
# [IMG_2716.jpg] Original size: (999, 750)
# [IMG_2716.jpg] No resize needed.
# [IMG_2716.jpg] Saved corrected image to /Users/liann/workspace/herbarium-processor/data/img/bucket/IMG_2716.jpg
# [IMG_2709.jpg] Original size: (750, 999)
# [IMG_2709.jpg] No resize needed.
# [IMG_2709.jpg] Saved corrected image to /Users/liann/workspace/herbarium-processor/data/img/bucket/IMG_2709.jpg

# %%
"""
Step 2: Calling the OCR AI model.
This step will call OCR and save the output to .json files in the tmp/ directory.

It will then build specimen labels based on the OCR output.
You do NOT need to edit this section.
"""

import json
import sys
import os
from herbarium_processor.core.ocr.ocr_client import OcrClient

ocr = OcrClient()

if image_path:
    for filename in os.listdir(image_path):
        path = os.path.join(image_path, filename)
        if filename.lower().endswith(".jpg") or filename.lower().endswith(".jpeg"):
            print(f"Processing {path}")
            ocr.extract_text_json(path)
# Out:
# Processing data/img/bucket/IMG_2716.jpg
# Saved visualized image with bounding boxes and sources to /Users/liann/workspace/herbarium-processor/tmp/ocr_bounding_IMG_2716.jpg
# [{'id': '1.1.1', 'text': 'LICHENS OF CALIFORNIA', 'bounding_box': [{'x': 467, 'y': 260}, {'x': 842, 'y': 260}, {'x': 842, 'y': 300}, {'x': 467, 'y': 300}], 'average_confidence': 0.97216548}, {'id': '1.1.2', 'text': 'Acarospora strigata ( Nyl . ) Jatta', 'bounding_box': [{'x': 431, 'y': 346}, {'x': 774, 'y': 346}, {'x': 774, 'y': 387}, {'x': 431, 'y': 387}], 'average_confidence': 0.9404115599999999}, {'id': '1.1.3', 'text': 'Mono Co.', 'bounding_box': [{'x': 397, 'y': 399}, {'x': 502, 'y': 399}, {'x': 502, 'y': 426}, {'x': 397, 'y': 426}], 'average_confidence': 0.97934638}, {'id': '1.1.4', 'text': 'Crooked Creek , UC White Mtns . Research Station', 'bounding_box': [{'x': 396, 'y': 405}, {'x': 885, 'y': 405}, {'x': 885, 'y': 458}, {'x': 396, 'y': 458}], 'average_confidence': 0.9537425066666666}, {'id': '1.1.5', 'text': "N37 ° 30 ' 18 road , East of Research Station .", 'bounding_box': [{'x': 393, 'y': 437}, {'x': 868, 'y': 437}, {'x': 868, 'y': 484}, {'x': 393, 'y': 484}], 'average_confidence': 0.9284240441666668}, {'id': '1.1.6', 'text': 'Dolomite outcrop " W118 ° 09 \' 11 "', 'bounding_box': [{'x': 390, 'y': 465}, {'x': 672, 'y': 465}, {'x': 672, 'y': 523}, {'x': 390, 'y': 523}], 'average_confidence': 0.9194459844444444}, {'id': '1.1.7', 'text': 'On dolomite in Bristlecone - limber pine forest', 'bounding_box': [{'x': 389, 'y': 498}, {'x': 915, 'y': 498}, {'x': 915, 'y': 543}, {'x': 389, 'y': 543}], 'average_confidence': 0.9828252737500001}, {'id': '1.1.8', 'text': "Elev . 9995 '", 'bounding_box': [{'x': 736, 'y': 568}, {'x': 859, 'y': 568}, {'x': 859, 'y': 592}, {'x': 736, 'y': 592}], 'average_confidence': 0.890956285}, {'id': '1.1.9', 'text': 'Coll :', 'bounding_box': [{'x': 381, 'y': 612}, {'x': 435, 'y': 612}, {'x': 435, 'y': 639}, {'x': 381, 'y': 639}], 'average_confidence': 0.96371865}, {'id': '1.1.10', 'text': 'Ronald & Judith Robertson 2 July 2005', 'bounding_box': [{'x': 446, 'y': 616}, {'x': 887, 'y': 616}, {'x': 887, 'y': 666}, {'x': 446, 'y': 666}], 'average_confidence': 0.9817287414285714}, {'id': '1.1.11', 'text': 'Det : Judith Robertson No. 9318b', 'bounding_box': [{'x': 379, 'y': 645}, {'x': 891, 'y': 645}, {'x': 891, 'y': 695}, {'x': 379, 'y': 695}], 'average_confidence': 0.9738780733333333}]
# Processing data/img/bucket/IMG_2709.jpg
# Saved visualized image with bounding boxes and sources to /Users/liann/workspace/herbarium-processor/tmp/ocr_bounding_IMG_2709.jpg
# [{'id': '1.1.1', 'text': 'Jatta ) .', 'bounding_box': [{'x': 402, 'y': 76}, {'x': 496, 'y': 76}, {'x': 496, 'y': 131}, {'x': 402, 'y': 131}], 'average_confidence': 0.6261868899999999}, {'id': '1.1.2', 'text': 'strigata Nyl (', 'bounding_box': [{'x': 396, 'y': 88}, {'x': 548, 'y': 88}, {'x': 548, 'y': 160}, {'x': 396, 'y': 160}], 'average_confidence': 0.7446503466666666}, {'id': '1.1.3', 'text': 'Acarospora', 'bounding_box': [{'x': 502, 'y': 135}, {'x': 636, 'y': 135}, {'x': 636, 'y': 174}, {'x': 502, 'y': 174}], 'average_confidence': 0.66208035}, {'id': '1.1.4', 'text': 'Reverside Hab Acarospora 1327', 'bounding_box': [{'x': 356, 'y': 198}, {'x': 630, 'y': 198}, {'x': 630, 'y': 441}, {'x': 356, 'y': 441}], 'average_confidence': 0.792632065}, {'id': '1.1.5', 'text': '.', 'bounding_box': [{'x': 398, 'y': 244}, {'x': 414, 'y': 244}, {'x': 414, 'y': 249}, {'x': 398, 'y': 249}], 'average_confidence': 0.9298776}, {'id': '1.1.6', 'text': 'Palm', 'bounding_box': [{'x': 392, 'y': 259}, {'x': 439, 'y': 259}, {'x': 439, 'y': 332}, {'x': 392, 'y': 332}], 'average_confidence': 0.72434044}, {'id': '1.1.7', 'text': 'co Springs Ex', 'bounding_box': [{'x': 355, 'y': 344}, {'x': 625, 'y': 344}, {'x': 625, 'y': 449}, {'x': 355, 'y': 449}], 'average_confidence': 0.8714038033333334}, {'id': '1.1.8', 'text': '.', 'bounding_box': [{'x': 355, 'y': 390}, {'x': 385, 'y': 390}, {'x': 385, 'y': 408}, {'x': 355, 'y': 408}], 'average_confidence': 0.79083544}, {'id': '1.1.9', 'text': 'Cal HERB', 'bounding_box': [{'x': 352, 'y': 405}, {'x': 623, 'y': 405}, {'x': 623, 'y': 473}, {'x': 352, 'y': 473}], 'average_confidence': 0.8101606349999999}, {'id': '1.1.10', 'text': '( Tiche peltasticta', 'bounding_box': [{'x': 380, 'y': 442}, {'x': 553, 'y': 442}, {'x': 553, 'y': 623}, {'x': 380, 'y': 623}], 'average_confidence': 0.72029424}, {'id': '1.1.11', 'text': 'H. .', 'bounding_box': [{'x': 600, 'y': 466}, {'x': 620, 'y': 466}, {'x': 620, 'y': 515}, {'x': 600, 'y': 515}], 'average_confidence': 0.94059585}, {'id': '1.1.12', 'text': 'werlite', 'bounding_box': [{'x': 375, 'y': 506}, {'x': 422, 'y': 506}, {'x': 422, 'y': 585}, {'x': 375, 'y': 585}], 'average_confidence': 0.61097115}, {'id': '1.1.13', 'text': 'E.', 'bounding_box': [{'x': 598, 'y': 528}, {'x': 617, 'y': 528}, {'x': 617, 'y': 553}, {'x': 598, 'y': 553}], 'average_confidence': 0.9758456}, {'id': '1.1.14', 'text': ') HASSE', 'bounding_box': [{'x': 375, 'y': 565}, {'x': 615, 'y': 565}, {'x': 615, 'y': 634}, {'x': 375, 'y': 634}], 'average_confidence': 0.916460835}, {'id': '1.1.15', 'text': '.', 'bounding_box': [{'x': 374, 'y': 589}, {'x': 416, 'y': 589}, {'x': 416, 'y': 608}, {'x': 374, 'y': 608}], 'average_confidence': 0.47771525}, {'id': '1.1.16', 'text': 'POMONA HERBARIUM & , .', 'bounding_box': [{'x': 50, 'y': 617}, {'x': 612, 'y': 617}, {'x': 612, 'y': 849}, {'x': 50, 'y': 849}], 'average_confidence': 0.7872728299999999}, {'id': '1.1.17', 'text': 'Zahlbrin', 'bounding_box': [{'x': 488, 'y': 653}, {'x': 544, 'y': 653}, {'x': 544, 'y': 777}, {'x': 488, 'y': 777}], 'average_confidence': 0.5750865}, {'id': '1.1.18', 'text': '245081', 'bounding_box': [{'x': 126, 'y': 690}, {'x': 159, 'y': 690}, {'x': 159, 'y': 834}, {'x': 126, 'y': 834}], 'average_confidence': 0.987219}, {'id': '1.1.19', 'text': '1993 NIVERSITY HERBARIUM', 'bounding_box': [{'x': 337, 'y': 718}, {'x': 462, 'y': 718}, {'x': 462, 'y': 800}, {'x': 337, 'y': 800}], 'average_confidence': 0.8708389799999999}, {'id': '1.1.20', 'text': 'COLLEGE UC', 'bounding_box': [{'x': 50, 'y': 751}, {'x': 441, 'y': 751}, {'x': 441, 'y': 866}, {'x': 50, 'y': 866}], 'average_confidence': 0.9649521999999999}, {'id': '1.1.21', 'text': 'OF .', 'bounding_box': [{'x': 383, 'y': 770}, {'x': 539, 'y': 770}, {'x': 539, 'y': 797}, {'x': 383, 'y': 797}], 'average_confidence': 0.65576273}, {'id': '1.1.22', 'text': 'CALIFORN OF THE . sc', 'bounding_box': [{'x': 378, 'y': 799}, {'x': 538, 'y': 799}, {'x': 538, 'y': 854}, {'x': 378, 'y': 854}], 'average_confidence': 0.69808271},  ...

# %%
"""
Step 3: Building the samples for the prompt based on the OCR output.

This section will automatically generate the list of specimen labels
based on the sampled paths defined above.

You do NOT need to edit this section.
"""

from herbarium_processor.core.types.specimen_label import SpecimenLabel
from pathlib import Path

target_examples = []

if image_path:
    for filename in os.listdir(image_path):
        if filename.startswith(".DS"):
            continue
        path = Path(os.path.join(image_path, filename))
        if path.suffix.lower() not in {".jpg", ".jpeg"}:
            continue
        ocr_file = Path("tmp") / f"ocr_ai_input_{path.stem}.json"
        if not ocr_file.exists():
            print(f"Skipping {filename}, OCR file not found: {ocr_file}")
            continue
        label = SpecimenLabel(
            id=path.stem,
            img_path=str(path),
            ocr_path=f"tmp/ocr_ai_input_{path.stem}.json",
        )
        target_examples.append(label)
        print("Saving specimen label with the following info:" + str(label))
# Out:
# Saving specimen label with the following info:SpecimenLabel(id='IMG_2716', img_path=PosixPath('/Users/liann/workspace/herbarium-processor/data/img/bucket/IMG_2716.jpg'), ocr_path=PosixPath('/Users/liann/workspace/herbarium-processor/tmp/ocr_ai_input_IMG_2716.json'))
# Saving specimen label with the following info:SpecimenLabel(id='IMG_2709', img_path=PosixPath('/Users/liann/workspace/herbarium-processor/data/img/bucket/IMG_2709.jpg'), ocr_path=PosixPath('/Users/liann/workspace/herbarium-processor/tmp/ocr_ai_input_IMG_2709.json'))

# %%
"""
Step 4: Calling the AI model

You do NOT need to edit this section.

"""

from herbarium_processor.core.inference.label_extraction_batch_runner import (
    LabelExtractionBatchRunner,
)

runner = LabelExtractionBatchRunner(
    output_csv_path=output_csv_path,
    system_instructions_path=system_instructions_path,
    prompt_builder=prompt_builder,
    targets=target_examples,
)
await runner.run_async()
# Out:
# [DEBUG] Text part 0: You are an AI assistant trained to extract structured data from herbarium specimen label images.
#
# You will be shown 3 label images and corresponding OCR blocks as examples. These examples include the correct structured JSON output. After that, you will be shown a fourth image (with OCR blocks) that you must process.
#
# Use both the image and the OCR output to extract only the following 21 fields as a valid JSON object using `snake_case` keys:
#
# * `label_header`
# * `scientific_name`
# * `field_collection_location_verbatim`
# * `county`
# * `state`
# * `country`
# * `verbatim_latitude`
# * `verbatim_longitude`
# * `elevation`
# * `habitat_information`
# * `field_collection_date`
# * `comment`
# * `field_collectors`
# * `field_collection_number`
# * `identifier`
# * `identification_date`
# * `exsiccatae`
# * `associated_taxa`
# * `old_scientific_name`
# * `old_identifier`
# * `old_identification_date`
#
#
# Return `null` for any field that is not clearly present or legible. Do **not** infer or fabricate any information. Do **not** return extra fields.
#
# ---
# **Example 1**
#
# Image:
#
# [DEBUG] Image part 1: mime=image/jpeg, size=92248 bytes
# [DEBUG] Image data_url prefix: ......
# [DEBUG] Text part 2:
#
# OCR Output:
# ```json
# [
#   {
#     "average_confidence": 0.9735246280000001,
#     "bounding_box": [
#       {
#         "x": 229,
#         "y": 175
#       },
#       {
#         "x": 839,
#         "y": 175
#       },
#       {
#         "x": 839,
#         "y": 211
#       },
#       {
#         "x": 229,
#         "y": 211
#       }
#     ],
#     "id": "1.1.1",
#     "text": "F. RENAULD \u0026 J. CARDOT"
#   },
#   {
#     "average_confidence": 0.9616529533333332,
#     "bounding_box": [
#       {
#         "x": 175,
#         "y": 237
#       },
#       {
#         "x": 890,
#         "y": 237
#       },
#       {
#         "x": 890,
#         "y": 287
#       },
#       {
#         "x": 175,
#         "y": 287
#       }
#     ],
#     "id": "1.1.2",
#     "text": "Musci europ\u00e6i exsiccati"
#   },
#   {
#     "average_confidence": 0.5832276,
#     "bounding_box": [
#       {
#         "x": 531,
#         "y": 301
#       },
#       {
#         "x": 597,
#         "y": 301
#       },
#       {
#         "x": 597,
#         "y": 315
#       },
#       {
#         "x": 531,
#         "y": 315
#       }
#     ],
#     "id": "1.1.3",
#     "text": "303"
#   },
#   {
#     "average_confidence": 0.831805994,
#     "bounding_box": [
#       {
#         "x": 151,
#         "y": 360
#       },
#       {
#         "x": 920,
#         "y": 360
#       },
#       {
#         "x": 920,
#         "y": 445
#       },
#       {
#         "x": 151,
#         "y": 445
#       }
#     ],
#     "id": "1.1.4",
#     "text": "N\u00ba30 . Fontinalis arvernica Ren-"
#   },
#   {
#     "average_confidence": 0.9345777649999999,
#     "bounding_box": [
#       {
#         "x": 86,
#         "y": 470
#       },
#       {
#         "x": 888,
#         "y": 470
#       },
#       {
#         "x": 888,
#         "y": 549
#       },
#       {
#         "x": 86,
#         "y": 549
#       }
#     ],
#     "id": "1.1.5",
#     "text": "In aquis profundis lacus Pavin Arverniae"
#   },
#   {
#     "average_confidence": 0.828987095,
#     "bounding_box": [
#       {
#         "x": 460,
#         "y": 553
#       },
#       {
#         "x": 873,
#         "y": 553
#       },
#       {
#         "x": 873,
#         "y": 642
#       },
#       {
#         "x": 460,
#         "y": 642
#       }
#     ],
#     "id": "1.1.6",
#     "text": "Leg . F. Renauld"
#   },
#   {
#     "average_confidence": 0.6125826249999999,
#     "bounding_box": [
#       {
#         "x": 69,
#         "y": 740
#       },
#       {
#         "x": 722,
#         "y": 740
#       },
#       {
#         "x": 722,
#         "y": 844
#       },
#       {
#         "x": 69,
#         "y": 844
#       }
#     ],
#     "id": "1.1.7",
#     "text": "Fontinalis autifystica"
#   },
#   {
#     "average_confidence": 0.44124288333333334,
#     "bounding_box": [
#       {
#         "x": 736,
#         "y": 783
#       },
#       {
#         "x": 856,
#         "y": 783
#       },
#       {
#         "x": 856,
#         "y": 852
#       },
#       {
#         "x": 736,
#         "y": 852
#       }
#     ],
#     "id": "1.1.8",
#     "text": "[ . ]"
#   },
#   {
#     "average_confidence": 0.802025325,
#     "bounding_box": [
#       {
#         "x": 71,
#         "y": 819
#       },
#       {
#         "x": 246,
#         "y": 819
#       },
#       {
#         "x": 246,
#         "y": 859
#       },
#       {
#         "x": 71,
#         "y": 859
#       }
#     ],
#     "id": "1.1.9",
#     "text": "Hedw ."
#   },
#   {
#     "average_confidence": 0.9705295266666667,
#     "bounding_box": [
#       {
#         "x": 98,
#         "y": 877
#       },
#       {
#         "x": 880,
#         "y": 877
#       },
#       {
#         "x": 880,
#         "y": 915
#       },
#       {
#         "x": 98,
#         "y": 915
#       }
#     ],
#     "id": "1.1.10",
#     "text": "Determined by Winona H. Welch 8-14-1945"
#   },
#   {
#     "average_confidence": 0.67041407,
#     "bounding_box": [
#       {
#         "x": 70,
#         "y": 915
#       },
#       {
#         "x": 142,
#         "y": 915
#       },
#       {
#         "x": 142,
#         "y": 938
#       },
#       {
#         "x": 70,
#         "y": 938
#       }
#     ],
#     "id": "1.1.11",
#     "text": "30 ."
#   }
# ]
# ```
#
# Correct Output:
# ```json
# {
#   "associated_taxa": null,
#   "comment": "In aquis profundis",
#   "country": "France",
#   "county": null,
#   "elevation": null,
#   "exsiccatae": "Musci europ\u00e6i exsiccati",
#   "field_collection_date": null,
#   "field_collection_location_verbatim": "lacus Pavin Arverniae",
#   "field_collection_number": "30",
#   "field_collectors": "[\u0027F. Renauld\u0027]",
#   "habitat_information": null,
#   "identification_date": "14-Aug-45",
#   "identifier": "Winona H. Welch",
#   "label_header": "F. RENAULD \u0026 J. CARDOT",
#   "old_identification_date": null,
#   "old_identifier": "Ren.",
#   "old_scientific_name": "Fontinalis avernica",
#   "scientific_name": "Fontinalis antipyretica Hedw.",
#   "state": null,
#   "verbatim_latitude": null,
#   "verbatim_longitude": null
# }
# ```
#
# ---
# **Example 2**
#
# Image:
#
# [DEBUG] Image part 3: mime=image/jpeg, size=63357 bytes
# [DEBUG] Image data_url prefix: ......
# [DEBUG] Text part 4:
#
# OCR Output:
# ```json
# [
#   {
#     "average_confidence": 0.984642865,
#     "bounding_box": [
#       {
#         "x": 300,
#         "y": 94
#       },
#       {
#         "x": 606,
#         "y": 94
#       },
#       {
#         "x": 606,
#         "y": 127
#       },
#       {
#         "x": 300,
#         "y": 127
#       }
#     ],
#     "id": "1.1.1",
#     "text": "MUSCI JAPONICI"
#   },
#   {
#     "average_confidence": 0.9760597423076922,
#     "bounding_box": [
#       {
#         "x": 76,
#         "y": 158
#       },
#       {
#         "x": 828,
#         "y": 158
#       },
#       {
#         "x": 828,
#         "y": 187
#       },
#       {
#         "x": 76,
#         "y": 187
#       }
#     ],
#     "id": "1.1.2",
#     "text": "Ser . 9 ( 1955 ) Edited by A. Noguchi \u0026 S. Hattori"
#   },
#   {
#     "average_confidence": 0.9795091333333333,
#     "bounding_box": [
#       {
#         "x": 74,
#         "y": 248
#       },
#       {
#         "x": 434,
#         "y": 248
#       },
#       {
#         "x": 434,
#         "y": 274
#       },
#       {
#         "x": 74,
#         "y": 274
#       }
#     ],
#     "id": "1.1.3",
#     "text": "420. Fontinalis antipyretica"
#   },
#   {
#     "average_confidence": 0.971444046,
#     "bounding_box": [
#       {
#         "x": 446,
#         "y": 250
#       },
#       {
#         "x": 582,
#         "y": 250
#       },
#       {
#         "x": 582,
#         "y": 274
#       },
#       {
#         "x": 446,
#         "y": 274
#       }
#     ],
#     "id": "1.1.4",
#     "text": "( L. ) Hedw ."
#   },
#   {
#     "average_confidence": 0.9811021606666667,
#     "bounding_box": [
#       {
#         "x": 76,
#         "y": 365
#       },
#       {
#         "x": 830,
#         "y": 365
#       },
#       {
#         "x": 830,
#         "y": 393
#       },
#       {
#         "x": 76,
#         "y": 393
#       }
#     ],
#     "id": "1.1.5",
#     "text": "Rocks submerged in stream , ca. 1500 m . alt . , near Azumi ,"
#   },
#   {
#     "average_confidence": 0.985448875,
#     "bounding_box": [
#       {
#         "x": 76,
#         "y": 398
#       },
#       {
#         "x": 316,
#         "y": 398
#       },
#       {
#         "x": 316,
#         "y": 424
#       },
#       {
#         "x": 76,
#         "y": 424
#       }
#     ],
#     "id": "1.1.6",
#     "text": "Nagano Prefecture"
#   },
#   {
#     "average_confidence": 0.7980332,
#     "bounding_box": [
#       {
#         "x": 801,
#         "y": 428
#       },
#       {
#         "x": 829,
#         "y": 428
#       },
#       {
#         "x": 829,
#         "y": 453
#       },
#       {
#         "x": 801,
#         "y": 453
#       }
#     ],
#     "id": "1.1.7",
#     "text": "OF"
#   },
#   {
#     "average_confidence": 0.9351292653333334,
#     "bounding_box": [
#       {
#         "x": 74,
#         "y": 428
#       },
#       {
#         "x": 860,
#         "y": 428
#       },
#       {
#         "x": 860,
#         "y": 471
#       },
#       {
#         "x": 74,
#         "y": 471
#       }
#     ],
#     "id": "1.1.8",
#     "text": "Coll . U. Mizushima ( Mrs. ) , September 29 , 1954 HERBARIUM OF THE"
#   },
#   {
#     "average_confidence": 0.68084073,
#     "bounding_box": [
#       {
#         "x": 750,
#         "y": 462
#       },
#       {
#         "x": 828,
#         "y": 462
#       },
#       {
#         "x": 828,
#         "y": 500
#       },
#       {
#         "x": 750,
#         "y": 500
#       }
#     ],
#     "id": "1.1.9",
#     "text": "UC"
#   },
#   {
#     "average_confidence": 0.9760237975,
#     "bounding_box": [
#       {
#         "x": 74,
#         "y": 479
#       },
#       {
#         "x": 290,
#         "y": 479
#       },
#       {
#         "x": 290,
#         "y": 506
#       },
#       {
#         "x": 74,
#         "y": 506
#       }
#     ],
#     "id": "1.1.10",
#     "text": "Det . A. Noguchi"
#   },
#   {
#     "average_confidence": 0.8101489133333333,
#     "bounding_box": [
#       {
#         "x": 698,
#         "y": 490
#       },
#       {
#         "x": 860,
#         "y": 490
#       },
#       {
#         "x": 860,
#         "y": 534
#       },
#       {
#         "x": 698,
#         "y": 534
#       }
#     ],
#     "id": "1.1.11",
#     "text": "FIERSITY OF CALIFOR"
#   },
#   {
#     "average_confidence": 0.7194973,
#     "bounding_box": [
#       {
#         "x": 332,
#         "y": 566
#       },
#       {
#         "x": 444,
#         "y": 566
#       },
#       {
#         "x": 444,
#         "y": 676
#       },
#       {
#         "x": 332,
#         "y": 676
#       }
#     ],
#     "id": "1.1.12",
#     "text": "UNIVERS"
#   },
#   {
#     "average_confidence": 0.9516384499999999,
#     "bounding_box": [
#       {
#         "x": 392,
#         "y": 570
#       },
#       {
#         "x": 593,
#         "y": 570
#       },
#       {
#         "x": 593,
#         "y": 602
#       },
#       {
#         "x": 392,
#         "y": 602
#       }
#     ],
#     "id": "1.1.13",
#     "text": "M 207518"
#   },
#   {
#     "average_confidence": 0.8396531,
#     "bounding_box": [
#       {
#         "x": 536,
#         "y": 559
#       },
#       {
#         "x": 669,
#         "y": 559
#       },
#       {
#         "x": 669,
#         "y": 680
#       },
#       {
#         "x": 536,
#         "y": 680
#       }
#     ],
#     "id": "1.1.14",
#     "text": "CALIFORNIA"
#   },
#   {
#     "average_confidence": 0.9783724,
#     "bounding_box": [
#       {
#         "x": 486,
#         "y": 653
#       },
#       {
#         "x": 522,
#         "y": 653
#       },
#       {
#         "x": 522,
#         "y": 672
#       },
#       {
#         "x": 486,
#         "y": 672
#       }
#     ],
#     "id": "1.1.15",
#     "text": "OF"
#   }
# ]
# ```
#
# Correct Output:
# ```json
# {
#   "associated_taxa": null,
#   "comment": "Ser. 9 (1955) Edited by A. Noguchi \u0026 S. Hattori",
#   "country": "Japan",
#   "county": null,
#   "elevation": "ca. 1500 m.",
#   "exsiccatae": null,
#   "field_collection_date": "29-Sep-54",
#   "field_collection_location_verbatim": "near Azumi",
#   "field_collection_number": null,
#   "field_collectors": "[\u0027U. Mizushima (Mrs.)\u0027]",
#   "habitat_information": "Rocks submerged in stream",
#   "identification_date": null,
#   "identifier": "A. Noguchi",
#   "label_header": "MUSCI JAPONICI",
#   "old_identification_date": null,
#   "old_identifier": null,
#   "old_scientific_name": null,
#   "scientific_name": "Fontinalis antipyretica (L.) Hedw.",
#   "state": "Nagano Prefecture",
#   "verbatim_latitude": null,
#   "verbatim_longitude": null
# }
# ```
#
# ---
# **Example 3**
#
# Image:
#
# [DEBUG] Image part 5: mime=image/jpeg, size=58885 bytes
# [DEBUG] Image data_url prefix: ......
# [DEBUG] Text part 6:
#
# OCR Output:
# ```json
# [
#   {
#     "average_confidence": 0.9877717,
#     "bounding_box": [
#       {
#         "x": 469,
#         "y": 38
#       },
#       {
#         "x": 630,
#         "y": 38
#       },
#       {
#         "x": 630,
#         "y": 62
#       },
#       {
#         "x": 469,
#         "y": 62
#       }
#     ],
#     "id": "1.1.1",
#     "text": "Duplicatum ex"
#   },
#   {
#     "average_confidence": 0.9869702433333334,
#     "bounding_box": [
#       {
#         "x": 344,
#         "y": 75
#       },
#       {
#         "x": 763,
#         "y": 75
#       },
#       {
#         "x": 763,
#         "y": 100
#       },
#       {
#         "x": 344,
#         "y": 100
#       }
#     ],
#     "id": "1.1.2",
#     "text": "CONSERVATORIO BOTANICO GENEVENSI"
#   },
#   {
#     "average_confidence": 0.99032766,
#     "bounding_box": [
#       {
#         "x": 493,
#         "y": 120
#       },
#       {
#         "x": 602,
#         "y": 120
#       },
#       {
#         "x": 602,
#         "y": 136
#       },
#       {
#         "x": 493,
#         "y": 136
#       }
#     ],
#     "id": "1.1.3",
#     "text": "HELVETIAE"
#   },
#   {
#     "average_confidence": 0.88217158,
#     "bounding_box": [
#       {
#         "x": 280,
#         "y": 168
#       },
#       {
#         "x": 490,
#         "y": 168
#       },
#       {
#         "x": 490,
#         "y": 192
#       },
#       {
#         "x": 280,
#         "y": 192
#       }
#     ],
#     "id": "1.1.4",
#     "text": "390 . Fontinalis"
#   },
#   {
#     "average_confidence": 0.9535369380000001,
#     "bounding_box": [
#       {
#         "x": 502,
#         "y": 171
#       },
#       {
#         "x": 796,
#         "y": 171
#       },
#       {
#         "x": 796,
#         "y": 199
#       },
#       {
#         "x": 502,
#         "y": 199
#       }
#     ],
#     "id": "1.1.5",
#     "text": "antipyretica L. ex Hedw ."
#   },
#   {
#     "average_confidence": 0.9365827622222223,
#     "bounding_box": [
#       {
#         "x": 202,
#         "y": 218
#       },
#       {
#         "x": 710,
#         "y": 218
#       },
#       {
#         "x": 710,
#         "y": 246
#       },
#       {
#         "x": 202,
#         "y": 246
#       }
#     ],
#     "id": "1.1.6",
#     "text": "Loc .: Suisse . Vaud . Commune de Chavannes"
#   },
#   {
#     "average_confidence": 0.9293862388888888,
#     "bounding_box": [
#       {
#         "x": 288,
#         "y": 230
#       },
#       {
#         "x": 844,
#         "y": 230
#       },
#       {
#         "x": 844,
#         "y": 274
#       },
#       {
#         "x": 288,
#         "y": 274
#       }
#     ],
#     "id": "1.1.7",
#     "text": "Cours de la Versoix ( rivi\u00e8re des Bois ."
#   },
#   {
#     "average_confidence": 0.9901602,
#     "bounding_box": [
#       {
#         "x": 638,
#         "y": 250
#       },
#       {
#         "x": 658,
#         "y": 250
#       },
#       {
#         "x": 658,
#         "y": 274
#       },
#       {
#         "x": 638,
#         "y": 274
#       }
#     ],
#     "id": "1.1.8",
#     "text": ") ."
#   },
#   {
#     "average_confidence": 0.8883680110000001,
#     "bounding_box": [
#       {
#         "x": 200,
#         "y": 272
#       },
#       {
#         "x": 846,
#         "y": 272
#       },
#       {
#         "x": 846,
#         "y": 303
#       },
#       {
#         "x": 200,
#         "y": 303
#       }
#     ],
#     "id": "1.1.9",
#     "text": "Leg . S. Vautier et J - D . Bersier"
#   },
#   {
#     "average_confidence": 0.9210517628571429,
#     "bounding_box": [
#       {
#         "x": 199,
#         "y": 296
#       },
#       {
#         "x": 734,
#         "y": 296
#       },
#       {
#         "x": 734,
#         "y": 326
#       },
#       {
#         "x": 199,
#         "y": 326
#       }
#     ],
#     "id": "1.1.10",
#     "text": "Date : 1 juin 1964 . Alt"
#   },
#   {
#     "average_confidence": 0.9414688275,
#     "bounding_box": [
#       {
#         "x": 736,
#         "y": 310
#       },
#       {
#         "x": 842,
#         "y": 310
#       },
#       {
#         "x": 842,
#         "y": 330
#       },
#       {
#         "x": 736,
#         "y": 330
#       }
#     ],
#     "id": "1.1.11",
#     "text": ". 464 m ."
#   },
#   {
#     "average_confidence": 0.960434021111111,
#     "bounding_box": [
#       {
#         "x": 199,
#         "y": 337
#       },
#       {
#         "x": 757,
#         "y": 337
#       },
#       {
#         "x": 757,
#         "y": 370
#       },
#       {
#         "x": 199,
#         "y": 370
#       }
#     ],
#     "id": "1.1.12",
#     "text": "Obs .: Sur les pierres submerg\u00e9es dans le lit"
#   },
#   {
#     "average_confidence": 0.9866670000000001,
#     "bounding_box": [
#       {
#         "x": 286,
#         "y": 350
#       },
#       {
#         "x": 832,
#         "y": 350
#       },
#       {
#         "x": 832,
#         "y": 388
#       },
#       {
#         "x": 286,
#         "y": 388
#       }
#     ],
#     "id": "1.1.13",
#     "text": "rivi\u00e8re de la"
#   },
#   {
#     "average_confidence": 0.9415124,
#     "bounding_box": [
#       {
#         "x": 374,
#         "y": 371
#       },
#       {
#         "x": 382,
#         "y": 371
#       },
#       {
#         "x": 382,
#         "y": 387
#       },
#       {
#         "x": 374,
#         "y": 387
#       }
#     ],
#     "id": "1.1.14",
#     "text": "."
#   },
#   {
#     "average_confidence": 0.9880059133333333,
#     "bounding_box": [
#       {
#         "x": 418,
#         "y": 564
#       },
#       {
#         "x": 610,
#         "y": 564
#       },
#       {
#         "x": 610,
#         "y": 616
#       },
#       {
#         "x": 418,
#         "y": 616
#       }
#     ],
#     "id": "1.1.15",
#     "text": "HERBARIUM OF THE"
#   },
#   {
#     "average_confidence": 0.7149779,
#     "bounding_box": [
#       {
#         "x": 386,
#         "y": 610
#       },
#       {
#         "x": 463,
#         "y": 610
#       },
#       {
#         "x": 463,
#         "y": 686
#       },
#       {
#         "x": 386,
#         "y": 686
#       }
#     ],
#     "id": "1.1.16",
#     "text": "CNIVER"
#   },
#   {
#     "average_confidence": 0.9897582,
#     "bounding_box": [
#       {
#         "x": 447,
#         "y": 610
#       },
#       {
#         "x": 581,
#         "y": 610
#       },
#       {
#         "x": 581,
#         "y": 644
#       },
#       {
#         "x": 447,
#         "y": 644
#       }
#     ],
#     "id": "1.1.17",
#     "text": "1318628"
#   }
# ]
# ```
#
# Correct Output:
# ```json
# {
#   "associated_taxa": null,
#   "comment": null,
#   "country": "Switzerland",
#   "county": null,
#   "elevation": "464 m.",
#   "exsiccatae": "Duplicatum ex CONSERVATORIO BOTANICO GENEVENSI HELVETIAE",
#   "field_collection_date": "1-Jun-64",
#   "field_collection_location_verbatim": "Vaud. Commune de Chavannes des Bois. Cours de la Versoix (rivi\u00e8re).",
#   "field_collection_number": "390",
#   "field_collectors": "[\u0027S. Vautier\u0027, \u0027J-D. Bersier\u0027]",
#   "habitat_information": "Sur les pierres submerg\u00e9es dans le lit de la rivi\u00e8re.",
#   "identification_date": "16-Aug-45",
#   "identifier": "Winona H. Welch",
#   "label_header": null,
#   "old_identification_date": null,
#   "old_identifier": null,
#   "old_scientific_name": null,
#   "scientific_name": "Fontinalis antipyretica L. ex Hedw.",
#   "state": "Vaud",
#   "verbatim_latitude": null,
#   "verbatim_longitude": null
# }
# ```
#
#
# ---
#
# **Now classify this image:**
#
# Image:
#
# [DEBUG] Image part 7: mime=image/jpeg, size=43882 bytes
# [DEBUG] Image data_url prefix: ......
# [DEBUG] Text part 8:
#
# OCR Output:
# ```json
# [
#   {
#     "average_confidence": 0.97216548,
#     "bounding_box": [
#       {
#         "x": 467,
#         "y": 260
#       },
#       {
#         "x": 842,
#         "y": 260
#       },
#       {
#         "x": 842,
#         "y": 300
#       },
#       {
#         "x": 467,
#         "y": 300
#       }
#     ],
#     "id": "1.1.1",
#     "text": "LICHENS OF CALIFORNIA"
#   },
#   {
#     "average_confidence": 0.9404115599999999,
#     "bounding_box": [
#       {
#         "x": 431,
#         "y": 346
#       },
#       {
#         "x": 774,
#         "y": 346
#       },
#       {
#         "x": 774,
#         "y": 387
#       },
#       {
#         "x": 431,
#         "y": 387
#       }
#     ],
#     "id": "1.1.2",
#     "text": "Acarospora strigata ( Nyl . ) Jatta"
#   },
#   {
#     "average_confidence": 0.97934638,
#     "bounding_box": [
#       {
#         "x": 397,
#         "y": 399
#       },
#       {
#         "x": 502,
#         "y": 399
#       },
#       {
#         "x": 502,
#         "y": 426
#       },
#       {
#         "x": 397,
#         "y": 426
#       }
#     ],
#     "id": "1.1.3",
#     "text": "Mono Co."
#   },
#   {
#     "average_confidence": 0.9537425066666666,
#     "bounding_box": [
#       {
#         "x": 396,
#         "y": 405
#       },
#       {
#         "x": 885,
#         "y": 405
#       },
#       {
#         "x": 885,
#         "y": 458
#       },
#       {
#         "x": 396,
#         "y": 458
#       }
#     ],
#     "id": "1.1.4",
#     "text": "Crooked Creek , UC White Mtns . Research Station"
#   },
#   {
#     "average_confidence": 0.9284240441666668,
#     "bounding_box": [
#       {
#         "x": 393,
#         "y": 437
#       },
#       {
#         "x": 868,
#         "y": 437
#       },
#       {
#         "x": 868,
#         "y": 484
#       },
#       {
#         "x": 393,
#         "y": 484
#       }
#     ],
#     "id": "1.1.5",
#     "text": "N37 \u00b0 30 \u0027 18 road , East of Research Station ."
#   },
#   {
#     "average_confidence": 0.9194459844444444,
#     "bounding_box": [
#       {
#         "x": 390,
#         "y": 465
#       },
#       {
#         "x": 672,
#         "y": 465
#       },
#       {
#         "x": 672,
#         "y": 523
#       },
#       {
#         "x": 390,
#         "y": 523
#       }
#     ],
#     "id": "1.1.6",
#     "text": "Dolomite outcrop \" W118 \u00b0 09 \u0027 11 \""
#   },
#   {
#     "average_confidence": 0.9828252737500001,
#     "bounding_box": [
#       {
#         "x": 389,
#         "y": 498
#       },
#       {
#         "x": 915,
#         "y": 498
#       },
#       {
#         "x": 915,
#         "y": 543
#       },
#       {
#         "x": 389,
#         "y": 543
#       }
#     ],
#     "id": "1.1.7",
#     "text": "On dolomite in Bristlecone - limber pine forest"
#   },
#   {
#     "average_confidence": 0.890956285,
#     "bounding_box": [
#       {
#         "x": 736,
#         "y": 568
#       },
#       {
#         "x": 859,
#         "y": 568
#       },
#       {
#         "x": 859,
#         "y": 592
#       },
#       {
#         "x": 736,
#         "y": 592
#       }
#     ],
#     "id": "1.1.8",
#     "text": "Elev . 9995 \u0027"
#   },
#   {
#     "average_confidence": 0.96371865,
#     "bounding_box": [
#       {
#         "x": 381,
#         "y": 612
#       },
#       {
#         "x": 435,
#         "y": 612
#       },
#       {
#         "x": 435,
#         "y": 639
#       },
#       {
#         "x": 381,
#         "y": 639
#       }
#     ],
#     "id": "1.1.9",
#     "text": "Coll :"
#   },
#   {
#     "average_confidence": 0.9817287414285714,
#     "bounding_box": [
#       {
#         "x": 446,
#         "y": 616
#       },
#       {
#         "x": 887,
#         "y": 616
#       },
#       {
#         "x": 887,
#         "y": 666
#       },
#       {
#         "x": 446,
#         "y": 666
#       }
#     ],
#     "id": "1.1.10",
#     "text": "Ronald \u0026 Judith Robertson 2 July 2005"
#   },
#   {
#     "average_confidence": 0.9738780733333333,
#     "bounding_box": [
#       {
#         "x": 379,
#         "y": 645
#       },
#       {
#         "x": 891,
#         "y": 645
#       },
#       {
#         "x": 891,
#         "y": 695
#       },
#       {
#         "x": 379,
#         "y": 695
#       }
#     ],
#     "id": "1.1.11",
#     "text": "Det : Judith Robertson No. 9318b"
#   }
# ]
# ```
#
# Return your output as a single valid JSON object with **only the fields listed above**. Be precise. Do not guess unknown fields.
# [DEBUG] Text part 0: You are an AI assistant trained to extract structured data from herbarium specimen label images.
#
# You will be shown 3 label images and corresponding OCR blocks as examples. These examples include the correct structured JSON output. After that, you will be shown a fourth image (with OCR blocks) that you must process.
#
# Use both the image and the OCR output to extract only the following 21 fields as a valid JSON object using `snake_case` keys:
#
# * `label_header`
# * `scientific_name`
# * `field_collection_location_verbatim`
# * `county`
# * `state`
# * `country`
# * `verbatim_latitude`
# * `verbatim_longitude`
# * `elevation`
# * `habitat_information`
# * `field_collection_date`
# * `comment`
# * `field_collectors`
# * `field_collection_number`
# * `identifier`
# * `identification_date`
# * `exsiccatae`
# * `associated_taxa`
# * `old_scientific_name`
# * `old_identifier`
# * `old_identification_date`
#
#
# Return `null` for any field that is not clearly present or legible. Do **not** infer or fabricate any information. Do **not** return extra fields.
#
# ---
# **Example 1**
#
# Image:
#
# [DEBUG] Image part 1: mime=image/jpeg, size=92248 bytes
# [DEBUG] Image data_url prefix: ......
# [DEBUG] Text part 2:
#
# OCR Output:
# ```json
# [
#   {
#     "average_confidence": 0.9735246280000001,
#     "bounding_box": [
#       {
#         "x": 229,
#         "y": 175
#       },
#       {
#         "x": 839,
#         "y": 175
#       },
#       {
#         "x": 839,
#         "y": 211
#       },
#       {
#         "x": 229,
#         "y": 211
#       }
#     ],
#     "id": "1.1.1",
#     "text": "F. RENAULD \u0026 J. CARDOT"
#   },
#   {
#     "average_confidence": 0.9616529533333332,
#     "bounding_box": [
#       {
#         "x": 175,
#         "y": 237
#       },
#       {
#         "x": 890,
#         "y": 237
#       },
#       {
#         "x": 890,
#         "y": 287
#       },
#       {
#         "x": 175,
#         "y": 287
#       }
#     ],
#     "id": "1.1.2",
#     "text": "Musci europ\u00e6i exsiccati"
#   },
#   {
#     "average_confidence": 0.5832276,
#     "bounding_box": [
#       {
#         "x": 531,
#         "y": 301
#       },
#       {
#         "x": 597,
#         "y": 301
#       },
#       {
#         "x": 597,
#         "y": 315
#       },
#       {
#         "x": 531,
#         "y": 315
#       }
#     ],
#     "id": "1.1.3",
#     "text": "303"
#   },
#   {
#     "average_confidence": 0.831805994,
#     "bounding_box": [
#       {
#         "x": 151,
#         "y": 360
#       },
#       {
#         "x": 920,
#         "y": 360
#       },
#       {
#         "x": 920,
#         "y": 445
#       },
#       {
#         "x": 151,
#         "y": 445
#       }
#     ],
#     "id": "1.1.4",
#     "text": "N\u00ba30 . Fontinalis arvernica Ren-"
#   },
#   {
#     "average_confidence": 0.9345777649999999,
#     "bounding_box": [
#       {
#         "x": 86,
#         "y": 470
#       },
#       {
#         "x": 888,
#         "y": 470
#       },
#       {
#         "x": 888,
#         "y": 549
#       },
#       {
#         "x": 86,
#         "y": 549
#       }
#     ],
#     "id": "1.1.5",
#     "text": "In aquis profundis lacus Pavin Arverniae"
#   },
#   {
#     "average_confidence": 0.828987095,
#     "bounding_box": [
#       {
#         "x": 460,
#         "y": 553
#       },
#       {
#         "x": 873,
#         "y": 553
#       },
#       {
#         "x": 873,
#         "y": 642
#       },
#       {
#         "x": 460,
#         "y": 642
#       }
#     ],
#     "id": "1.1.6",
#     "text": "Leg . F. Renauld"
#   },
#   {
#     "average_confidence": 0.6125826249999999,
#     "bounding_box": [
#       {
#         "x": 69,
#         "y": 740
#       },
#       {
#         "x": 722,
#         "y": 740
#       },
#       {
#         "x": 722,
#         "y": 844
#       },
#       {
#         "x": 69,
#         "y": 844
#       }
#     ],
#     "id": "1.1.7",
#     "text": "Fontinalis autifystica"
#   },
#   {
#     "average_confidence": 0.44124288333333334,
#     "bounding_box": [
#       {
#         "x": 736,
#         "y": 783
#       },
#       {
#         "x": 856,
#         "y": 783
#       },
#       {
#         "x": 856,
#         "y": 852
#       },
#       {
#         "x": 736,
#         "y": 852
#       }
#     ],
#     "id": "1.1.8",
#     "text": "[ . ]"
#   },
#   {
#     "average_confidence": 0.802025325,
#     "bounding_box": [
#       {
#         "x": 71,
#         "y": 819
#       },
#       {
#         "x": 246,
#         "y": 819
#       },
#       {
#         "x": 246,
#         "y": 859
#       },
#       {
#         "x": 71,
#         "y": 859
#       }
#     ],
#     "id": "1.1.9",
#     "text": "Hedw ."
#   },
#   {
#     "average_confidence": 0.9705295266666667,
#     "bounding_box": [
#       {
#         "x": 98,
#         "y": 877
#       },
#       {
#         "x": 880,
#         "y": 877
#       },
#       {
#         "x": 880,
#         "y": 915
#       },
#       {
#         "x": 98,
#         "y": 915
#       }
#     ],
#     "id": "1.1.10",
#     "text": "Determined by Winona H. Welch 8-14-1945"
#   },
#   {
#     "average_confidence": 0.67041407,
#     "bounding_box": [
#       {
#         "x": 70,
#         "y": 915
#       },
#       {
#         "x": 142,
#         "y": 915
#       },
#       {
#         "x": 142,
#         "y": 938
#       },
#       {
#         "x": 70,
#         "y": 938
#       }
#     ],
#     "id": "1.1.11",
#     "text": "30 ."
#   }
# ]
# ```
#
# Correct Output:
# ```json
# {
#   "associated_taxa": null,
#   "comment": "In aquis profundis",
#   "country": "France",
#   "county": null,
#   "elevation": null,
#   "exsiccatae": "Musci europ\u00e6i exsiccati",
#   "field_collection_date": null,
#   "field_collection_location_verbatim": "lacus Pavin Arverniae",
#   "field_collection_number": "30",
#   "field_collectors": "[\u0027F. Renauld\u0027]",
#   "habitat_information": null,
#   "identification_date": "14-Aug-45",
#   "identifier": "Winona H. Welch",
#   "label_header": "F. RENAULD \u0026 J. CARDOT",
#   "old_identification_date": null,
#   "old_identifier": "Ren.",
#   "old_scientific_name": "Fontinalis avernica",
#   "scientific_name": "Fontinalis antipyretica Hedw.",
#   "state": null,
#   "verbatim_latitude": null,
#   "verbatim_longitude": null
# }
# ```
#
# ---
# **Example 2**
#
# Image:
#
# [DEBUG] Image part 3: mime=image/jpeg, size=63357 bytes
# [DEBUG] Image data_url prefix: ......
# [DEBUG] Text part 4:
#
# OCR Output:
# ```json
# [
#   {
#     "average_confidence": 0.984642865,
#     "bounding_box": [
#       {
#         "x": 300,
#         "y": 94
#       },
#       {
#         "x": 606,
#         "y": 94
#       },
#       {
#         "x": 606,
#         "y": 127
#       },
#       {
#         "x": 300,
#         "y": 127
#       }
#     ],
#     "id": "1.1.1",
#     "text": "MUSCI JAPONICI"
#   },
#   {
#     "average_confidence": 0.9760597423076922,
#     "bounding_box": [
#       {
#         "x": 76,
#         "y": 158
#       },
#       {
#         "x": 828,
#         "y": 158
#       },
#       {
#         "x": 828,
#         "y": 187
#       },
#       {
#         "x": 76,
#         "y": 187
#       }
#     ],
#     "id": "1.1.2",
#     "text": "Ser . 9 ( 1955 ) Edited by A. Noguchi \u0026 S. Hattori"
#   },
#   {
#     "average_confidence": 0.9795091333333333,
#     "bounding_box": [
#       {
#         "x": 74,
#         "y": 248
#       },
#       {
#         "x": 434,
#         "y": 248
#       },
#       {
#         "x": 434,
#         "y": 274
#       },
#       {
#         "x": 74,
#         "y": 274
#       }
#     ],
#     "id": "1.1.3",
#     "text": "420. Fontinalis antipyretica"
#   },
#   {
#     "average_confidence": 0.971444046,
#     "bounding_box": [
#       {
#         "x": 446,
#         "y": 250
#       },
#       {
#         "x": 582,
#         "y": 250
#       },
#       {
#         "x": 582,
#         "y": 274
#       },
#       {
#         "x": 446,
#         "y": 274
#       }
#     ],
#     "id": "1.1.4",
#     "text": "( L. ) Hedw ."
#   },
#   {
#     "average_confidence": 0.9811021606666667,
#     "bounding_box": [
#       {
#         "x": 76,
#         "y": 365
#       },
#       {
#         "x": 830,
#         "y": 365
#       },
#       {
#         "x": 830,
#         "y": 393
#       },
#       {
#         "x": 76,
#         "y": 393
#       }
#     ],
#     "id": "1.1.5",
#     "text": "Rocks submerged in stream , ca. 1500 m . alt . , near Azumi ,"
#   },
#   {
#     "average_confidence": 0.985448875,
#     "bounding_box": [
#       {
#         "x": 76,
#         "y": 398
#       },
#       {
#         "x": 316,
#         "y": 398
#       },
#       {
#         "x": 316,
#         "y": 424
#       },
#       {
#         "x": 76,
#         "y": 424
#       }
#     ],
#     "id": "1.1.6",
#     "text": "Nagano Prefecture"
#   },
#   {
#     "average_confidence": 0.7980332,
#     "bounding_box": [
#       {
#         "x": 801,
#         "y": 428
#       },
#       {
#         "x": 829,
#         "y": 428
#       },
#       {
#         "x": 829,
#         "y": 453
#       },
#       {
#         "x": 801,
#         "y": 453
#       }
#     ],
#     "id": "1.1.7",
#     "text": "OF"
#   },
#   {
#     "average_confidence": 0.9351292653333334,
#     "bounding_box": [
#       {
#         "x": 74,
#         "y": 428
#       },
#       {
#         "x": 860,
#         "y": 428
#       },
#       {
#         "x": 860,
#         "y": 471
#       },
#       {
#         "x": 74,
#         "y": 471
#       }
#     ],
#     "id": "1.1.8",
#     "text": "Coll . U. Mizushima ( Mrs. ) , September 29 , 1954 HERBARIUM OF THE"
#   },
#   {
#     "average_confidence": 0.68084073,
#     "bounding_box": [
#       {
#         "x": 750,
#         "y": 462
#       },
#       {
#         "x": 828,
#         "y": 462
#       },
#       {
#         "x": 828,
#         "y": 500
#       },
#       {
#         "x": 750,
#         "y": 500
#       }
#     ],
#     "id": "1.1.9",
#     "text": "UC"
#   },
#   {
#     "average_confidence": 0.9760237975,
#     "bounding_box": [
#       {
#         "x": 74,
#         "y": 479
#       },
#       {
#         "x": 290,
#         "y": 479
#       },
#       {
#         "x": 290,
#         "y": 506
#       },
#       {
#         "x": 74,
#         "y": 506
#       }
#     ],
#     "id": "1.1.10",
#     "text": "Det . A. Noguchi"
#   },
#   {
#     "average_confidence": 0.8101489133333333,
#     "bounding_box": [
#       {
#         "x": 698,
#         "y": 490
#       },
#       {
#         "x": 860,
#         "y": 490
#       },
#       {
#         "x": 860,
#         "y": 534
#       },
#       {
#         "x": 698,
#         "y": 534
#       }
#     ],
#     "id": "1.1.11",
#     "text": "FIERSITY OF CALIFOR"
#   },
#   {
#     "average_confidence": 0.7194973,
#     "bounding_box": [
#       {
#         "x": 332,
#         "y": 566
#       },
#       {
#         "x": 444,
#         "y": 566
#       },
#       {
#         "x": 444,
#         "y": 676
#       },
#       {
#         "x": 332,
#         "y": 676
#       }
#     ],
#     "id": "1.1.12",
#     "text": "UNIVERS"
#   },
#   {
#     "average_confidence": 0.9516384499999999,
#     "bounding_box": [
#       {
#         "x": 392,
#         "y": 570
#       },
#       {
#         "x": 593,
#         "y": 570
#       },
#       {
#         "x": 593,
#         "y": 602
#       },
#       {
#         "x": 392,
#         "y": 602
#       }
#     ],
#     "id": "1.1.13",
#     "text": "M 207518"
#   },
#   {
#     "average_confidence": 0.8396531,
#     "bounding_box": [
#       {
#         "x": 536,
#         "y": 559
#       },
#       {
#         "x": 669,
#         "y": 559
#       },
#       {
#         "x": 669,
#         "y": 680
#       },
#       {
#         "x": 536,
#         "y": 680
#       }
#     ],
#     "id": "1.1.14",
#     "text": "CALIFORNIA"
#   },
#   {
#     "average_confidence": 0.9783724,
#     "bounding_box": [
#       {
#         "x": 486,
#         "y": 653
#       },
#       {
#         "x": 522,
#         "y": 653
#       },
#       {
#         "x": 522,
#         "y": 672
#       },
#       {
#         "x": 486,
#         "y": 672
#       }
#     ],
#     "id": "1.1.15",
#     "text": "OF"
#   }
# ]
# ```
#
# Correct Output:
# ```json
# {
#   "associated_taxa": null,
#   "comment": "Ser. 9 (1955) Edited by A. Noguchi \u0026 S. Hattori",
#   "country": "Japan",
#   "county": null,
#   "elevation": "ca. 1500 m.",
#   "exsiccatae": null,
#   "field_collection_date": "29-Sep-54",
#   "field_collection_location_verbatim": "near Azumi",
#   "field_collection_number": null,
#   "field_collectors": "[\u0027U. Mizushima (Mrs.)\u0027]",
#   "habitat_information": "Rocks submerged in stream",
#   "identification_date": null,
#   "identifier": "A. Noguchi",
#   "label_header": "MUSCI JAPONICI",
#   "old_identification_date": null,
#   "old_identifier": null,
#   "old_scientific_name": null,
#   "scientific_name": "Fontinalis antipyretica (L.) Hedw.",
#   "state": "Nagano Prefecture",
#   "verbatim_latitude": null,
#   "verbatim_longitude": null
# }
# ```
#
# ---
# **Example 3**
#
# Image:
#
# [DEBUG] Image part 5: mime=image/jpeg, size=58885 bytes
# [DEBUG] Image data_url prefix: ......
# [DEBUG] Text part 6:
#
# OCR Output:
# ```json
# [
#   {
#     "average_confidence": 0.9877717,
#     "bounding_box": [
#       {
#         "x": 469,
#         "y": 38
#       },
#       {
#         "x": 630,
#         "y": 38
#       },
#       {
#         "x": 630,
#         "y": 62
#       },
#       {
#         "x": 469,
#         "y": 62
#       }
#     ],
#     "id": "1.1.1",
#     "text": "Duplicatum ex"
#   },
#   {
#     "average_confidence": 0.9869702433333334,
#     "bounding_box": [
#       {
#         "x": 344,
#         "y": 75
#       },
#       {
#         "x": 763,
#         "y": 75
#       },
#       {
#         "x": 763,
#         "y": 100
#       },
#       {
#         "x": 344,
#         "y": 100
#       }
#     ],
#     "id": "1.1.2",
#     "text": "CONSERVATORIO BOTANICO GENEVENSI"
#   },
#   {
#     "average_confidence": 0.99032766,
#     "bounding_box": [
#       {
#         "x": 493,
#         "y": 120
#       },
#       {
#         "x": 602,
#         "y": 120
#       },
#       {
#         "x": 602,
#         "y": 136
#       },
#       {
#         "x": 493,
#         "y": 136
#       }
#     ],
#     "id": "1.1.3",
#     "text": "HELVETIAE"
#   },
#   {
#     "average_confidence": 0.88217158,
#     "bounding_box": [
#       {
#         "x": 280,
#         "y": 168
#       },
#       {
#         "x": 490,
#         "y": 168
#       },
#       {
#         "x": 490,
#         "y": 192
#       },
#       {
#         "x": 280,
#         "y": 192
#       }
#     ],
#     "id": "1.1.4",
#     "text": "390 . Fontinalis"
#   },
#   {
#     "average_confidence": 0.9535369380000001,
#     "bounding_box": [
#       {
#         "x": 502,
#         "y": 171
#       },
#       {
#         "x": 796,
#         "y": 171
#       },
#       {
#         "x": 796,
#         "y": 199
#       },
#       {
#         "x": 502,
#         "y": 199
#       }
#     ],
#     "id": "1.1.5",
#     "text": "antipyretica L. ex Hedw ."
#   },
#   {
#     "average_confidence": 0.9365827622222223,
#     "bounding_box": [
#       {
#         "x": 202,
#         "y": 218
#       },
#       {
#         "x": 710,
#         "y": 218
#       },
#       {
#         "x": 710,
#         "y": 246
#       },
#       {
#         "x": 202,
#         "y": 246
#       }
#     ],
#     "id": "1.1.6",
#     "text": "Loc .: Suisse . Vaud . Commune de Chavannes"
#   },
#   {
#     "average_confidence": 0.9293862388888888,
#     "bounding_box": [
#       {
#         "x": 288,
#         "y": 230
#       },
#       {
#         "x": 844,
#         "y": 230
#       },
#       {
#         "x": 844,
#         "y": 274
#       },
#       {
#         "x": 288,
#         "y": 274
#       }
#     ],
#     "id": "1.1.7",
#     "text": "Cours de la Versoix ( rivi\u00e8re des Bois ."
#   },
#   {
#     "average_confidence": 0.9901602,
#     "bounding_box": [
#       {
#         "x": 638,
#         "y": 250
#       },
#       {
#         "x": 658,
#         "y": 250
#       },
#       {
#         "x": 658,
#         "y": 274
#       },
#       {
#         "x": 638,
#         "y": 274
#       }
#     ],
#     "id": "1.1.8",
#     "text": ") ."
#   },
#   {
#     "average_confidence": 0.8883680110000001,
#     "bounding_box": [
#       {
#         "x": 200,
#         "y": 272
#       },
#       {
#         "x": 846,
#         "y": 272
#       },
#       {
#         "x": 846,
#         "y": 303
#       },
#       {
#         "x": 200,
#         "y": 303
#       }
#     ],
#     "id": "1.1.9",
#     "text": "Leg . S. Vautier et J - D . Bersier"
#   },
#   {
#     "average_confidence": 0.9210517628571429,
#     "bounding_box": [
#       {
#         "x": 199,
#         "y": 296
#       },
#       {
#         "x": 734,
#         "y": 296
#       },
#       {
#         "x": 734,
#         "y": 326
#       },
#       {
#         "x": 199,
#         "y": 326
#       }
#     ],
#     "id": "1.1.10",
#     "text": "Date : 1 juin 1964 . Alt"
#   },
#   {
#     "average_confidence": 0.9414688275,
#     "bounding_box": [
#       {
#         "x": 736,
#         "y": 310
#       },
#       {
#         "x": 842,
#         "y": 310
#       },
#       {
#         "x": 842,
#         "y": 330
#       },
#       {
#         "x": 736,
#         "y": 330
#       }
#     ],
#     "id": "1.1.11",
#     "text": ". 464 m ."
#   },
#   {
#     "average_confidence": 0.960434021111111,
#     "bounding_box": [
#       {
#         "x": 199,
#         "y": 337
#       },
#       {
#         "x": 757,
#         "y": 337
#       },
#       {
#         "x": 757,
#         "y": 370
#       },
#       {
#         "x": 199,
#         "y": 370
#       }
#     ],
#     "id": "1.1.12",
#     "text": "Obs .: Sur les pierres submerg\u00e9es dans le lit"
#   },
#   {
#     "average_confidence": 0.9866670000000001,
#     "bounding_box": [
#       {
#         "x": 286,
#         "y": 350
#       },
#       {
#         "x": 832,
#         "y": 350
#       },
#       {
#         "x": 832,
#         "y": 388
#       },
#       {
#         "x": 286,
#         "y": 388
#       }
#     ],
#     "id": "1.1.13",
#     "text": "rivi\u00e8re de la"
#   },
#   {
#     "average_confidence": 0.9415124,
#     "bounding_box": [
#       {
#         "x": 374,
#         "y": 371
#       },
#       {
#         "x": 382,
#         "y": 371
#       },
#       {
#         "x": 382,
#         "y": 387
#       },
#       {
#         "x": 374,
#         "y": 387
#       }
#     ],
#     "id": "1.1.14",
#     "text": "."
#   },
#   {
#     "average_confidence": 0.9880059133333333,
#     "bounding_box": [
#       {
#         "x": 418,
#         "y": 564
#       },
#       {
#         "x": 610,
#         "y": 564
#       },
#       {
#         "x": 610,
#         "y": 616
#       },
#       {
#         "x": 418,
#         "y": 616
#       }
#     ],
#     "id": "1.1.15",
#     "text": "HERBARIUM OF THE"
#   },
#   {
#     "average_confidence": 0.7149779,
#     "bounding_box": [
#       {
#         "x": 386,
#         "y": 610
#       },
#       {
#         "x": 463,
#         "y": 610
#       },
#       {
#         "x": 463,
#         "y": 686
#       },
#       {
#         "x": 386,
#         "y": 686
#       }
#     ],
#     "id": "1.1.16",
#     "text": "CNIVER"
#   },
#   {
#     "average_confidence": 0.9897582,
#     "bounding_box": [
#       {
#         "x": 447,
#         "y": 610
#       },
#       {
#         "x": 581,
#         "y": 610
#       },
#       {
#         "x": 581,
#         "y": 644
#       },
#       {
#         "x": 447,
#         "y": 644
#       }
#     ],
#     "id": "1.1.17",
#     "text": "1318628"
#   }
# ]
# ```
#
# Correct Output:
# ```json
# {
#   "associated_taxa": null,
#   "comment": null,
#   "country": "Switzerland",
#   "county": null,
#   "elevation": "464 m.",
#   "exsiccatae": "Duplicatum ex CONSERVATORIO BOTANICO GENEVENSI HELVETIAE",
#   "field_collection_date": "1-Jun-64",
#   "field_collection_location_verbatim": "Vaud. Commune de Chavannes des Bois. Cours de la Versoix (rivi\u00e8re).",
#   "field_collection_number": "390",
#   "field_collectors": "[\u0027S. Vautier\u0027, \u0027J-D. Bersier\u0027]",
#   "habitat_information": "Sur les pierres submerg\u00e9es dans le lit de la rivi\u00e8re.",
#   "identification_date": "16-Aug-45",
#   "identifier": "Winona H. Welch",
#   "label_header": null,
#   "old_identification_date": null,
#   "old_identifier": null,
#   "old_scientific_name": null,
#   "scientific_name": "Fontinalis antipyretica L. ex Hedw.",
#   "state": "Vaud",
#   "verbatim_latitude": null,
#   "verbatim_longitude": null
# }
# ```
#
#
# ---
#
# **Now classify this image:**
#
# Image:
#
# [DEBUG] Image part 7: mime=image/jpeg, size=67549 bytes
# [DEBUG] Image data_url prefix: ......
# [DEBUG] Text part 8:
#
# OCR Output:
# ```json
# [
#   {
#     "average_confidence": 0.6261868899999999,
#     "bounding_box": [
#       {
#         "x": 402,
#         "y": 76
#       },
#       {
#         "x": 496,
#         "y": 76
#       },
#       {
#         "x": 496,
#         "y": 131
#       },
#       {
#         "x": 402,
#         "y": 131
#       }
#     ],
#     "id": "1.1.1",
#     "text": "Jatta ) ."
#   },
#   {
#     "average_confidence": 0.7446503466666666,
#     "bounding_box": [
#       {
#         "x": 396,
#         "y": 88
#       },
#       {
#         "x": 548,
#         "y": 88
#       },
#       {
#         "x": 548,
#         "y": 160
#       },
#       {
#         "x": 396,
#         "y": 160
#       }
#     ],
#     "id": "1.1.2",
#     "text": "strigata Nyl ("
#   },
#   {
#     "average_confidence": 0.66208035,
#     "bounding_box": [
#       {
#         "x": 502,
#         "y": 135
#       },
#       {
#         "x": 636,
#         "y": 135
#       },
#       {
#         "x": 636,
#         "y": 174
#       },
#       {
#         "x": 502,
#         "y": 174
#       }
#     ],
#     "id": "1.1.3",
#     "text": "Acarospora"
#   },
#   {
#     "average_confidence": 0.792632065,
#     "bounding_box": [
#       {
#         "x": 356,
#         "y": 198
#       },
#       {
#         "x": 630,
#         "y": 198
#       },
#       {
#         "x": 630,
#         "y": 441
#       },
#       {
#         "x": 356,
#         "y": 441
#       }
#     ],
#     "id": "1.1.4",
#     "text": "Reverside Hab Acarospora 1327"
#   },
#   {
#     "average_confidence": 0.9298776,
#     "bounding_box": [
#       {
#         "x": 398,
#         "y": 244
#       },
#       {
#         "x": 414,
#         "y": 244
#       },
#       {
#         "x": 414,
#         "y": 249
#       },
#       {
#         "x": 398,
#         "y": 249
#       }
#     ],
#     "id": "1.1.5",
#     "text": "."
#   },
#   {
#     "average_confidence": 0.72434044,
#     "bounding_box": [
#       {
#         "x": 392,
#         "y": 259
#       },
#       {
#         "x": 439,
#         "y": 259
#       },
#       {
#         "x": 439,
#         "y": 332
#       },
#       {
#         "x": 392,
#         "y": 332
#       }
#     ],
#     "id": "1.1.6",
#     "text": "Palm"
#   },
#   {
#     "average_confidence": 0.8714038033333334,
#     "bounding_box": [
#       {
#         "x": 355,
#         "y": 344
#       },
#       {
#         "x": 625,
#         "y": 344
#       },
#       {
#         "x": 625,
#         "y": 449
#       },
#       {
#         "x": 355,
#         "y": 449
#       }
#     ],
#     "id": "1.1.7",
#     "text": "co Springs Ex"
#   },
#   {
#     "average_confidence": 0.79083544,
#     "bounding_box": [
#       {
#         "x": 355,
#         "y": 390
#       },
#       {
#         "x": 385,
#         "y": 390
#       },
#       {
#         "x": 385,
#         "y": 408
#       },
#       {
#         "x": 355,
#         "y": 408
#       }
#     ],
#     "id": "1.1.8",
#     "text": "."
#   },
#   {
#     "average_confidence": 0.8101606349999999,
#     "bounding_box": [
#       {
#         "x": 352,
#         "y": 405
#       },
#       {
#         "x": 623,
#         "y": 405
#       },
#       {
#         "x": 623,
#         "y": 473
#       },
#       {
#         "x": 352,
#         "y": 473
#       }
#     ],
#     "id": "1.1.9",
#     "text": "Cal HERB"
#   },
#   {
#     "average_confidence": 0.72029424,
#     "bounding_box": [
#       {
#         "x": 380,
#         "y": 442
#       },
#       {
#         "x": 553,
#         "y": 442
#       },
#       {
#         "x": 553,
#         "y": 623
#       },
#       {
#         "x": 380,
#         "y": 623
#       }
#     ],
#     "id": "1.1.10",
#     "text": "( Tiche peltasticta"
#   },
#   {
#     "average_confidence": 0.94059585,
#     "bounding_box": [
#       {
#         "x": 600,
#         "y": 466
#       },
#       {
#         "x": 620,
#         "y": 466
#       },
#       {
#         "x": 620,
#         "y": 515
#       },
#       {
#         "x": 600,
#         "y": 515
#       }
#     ],
#     "id": "1.1.11",
#     "text": "H. ."
#   },
#   {
#     "average_confidence": 0.61097115,
#     "bounding_box": [
#       {
#         "x": 375,
#         "y": 506
#       },
#       {
#         "x": 422,
#         "y": 506
#       },
#       {
#         "x": 422,
#         "y": 585
#       },
#       {
#         "x": 375,
#         "y": 585
#       }
#     ],
#     "id": "1.1.12",
#     "text": "werlite"
#   },
#   {
#     "average_confidence": 0.9758456,
#     "bounding_box": [
#       {
#         "x": 598,
#         "y": 528
#       },
#       {
#         "x": 617,
#         "y": 528
#       },
#       {
#         "x": 617,
#         "y": 553
#       },
#       {
#         "x": 598,
#         "y": 553
#       }
#     ],
#     "id": "1.1.13",
#     "text": "E."
#   },
#   {
#     "average_confidence": 0.916460835,
#     "bounding_box": [
#       {
#         "x": 375,
#         "y": 565
#       },
#       {
#         "x": 615,
#         "y": 565
#       },
#       {
#         "x": 615,
#         "y": 634
#       },
#       {
#         "x": 375,
#         "y": 634
#       }
#     ],
#     "id": "1.1.14",
#     "text": ") HASSE"
#   },
#   {
#     "average_confidence": 0.47771525,
#     "bounding_box": [
#       {
#         "x": 374,
#         "y": 589
#       },
#       {
#         "x": 416,
#         "y": 589
#       },
#       {
#         "x": 416,
#         "y": 608
#       },
#       {
#         "x": 374,
#         "y": 608
#       }
#     ],
#     "id": "1.1.15",
#     "text": "."
#   },
#   {
#     "average_confidence": 0.7872728299999999,
#     "bounding_box": [
#       {
#         "x": 50,
#         "y": 617
#       },
#       {
#         "x": 612,
#         "y": 617
#       },
#       {
#         "x": 612,
#         "y": 849
#       },
#       {
#         "x": 50,
#         "y": 849
#       }
#     ],
#     "id": "1.1.16",
#     "text": "POMONA HERBARIUM \u0026 , ."
#   },
#   {
#     "average_confidence": 0.5750865,
#     "bounding_box": [
#       {
#         "x": 488,
#         "y": 653
#       },
#       {
#         "x": 544,
#         "y": 653
#       },
#       {
#         "x": 544,
#         "y": 777
#       },
#       {
#         "x": 488,
#         "y": 777
#       }
#     ],
#     "id": "1.1.17",
#     "text": "Zahlbrin"
#   },
#   {
#     "average_confidence": 0.987219,
#     "bounding_box": [
#       {
#         "x": 126,
#         "y": 690
#       },
#       {
#         "x": 159,
#         "y": 690
#       },
#       {
#         "x": 159,
#         "y": 834
#       },
#       {
#         "x": 126,
#         "y": 834
#       }
#     ],
#     "id": "1.1.18",
#     "text": "245081"
#   },
#   {
#     "average_confidence": 0.8708389799999999,
#     "bounding_box": [
#       {
#         "x": 337,
#         "y": 718
#       },
#       {
#         "x": 462,
#         "y": 718
#       },
#       {
#         "x": 462,
#         "y": 800
#       },
#       {
#         "x": 337,
#         "y": 800
#       }
#     ],
#     "id": "1.1.19",
#     "text": "1993 NIVERSITY HERBARIUM"
#   },
#   {
#     "average_confidence": 0.9649521999999999,
#     "bounding_box": [
#       {
#         "x": 50,
#         "y": 751
#       },
#       {
#         "x": 441,
#         "y": 751
#       },
#       {
#         "x": 441,
#         "y": 866
#       },
#       {
#         "x": 50,
#         "y": 866
#       }
#     ],
#     "id": "1.1.20",
#     "text": "COLLEGE UC"
#   },
#   {
#     "average_confidence": 0.65576273,
#     "bounding_box": [
#       {
#         "x": 383,
#         "y": 770
#       },
#       {
#         "x": 539,
#         "y": 770
#       },
#       {
#         "x": 539,
#         "y": 797
#       },
#       {
#         "x": 383,
#         "y": 797
#       }
#     ],
#     "id": "1.1.21",
#     "text": "OF ."
#   },
#   {
#     "average_confidence": 0.69808271,
#     "bounding_box": [
#       {
#         "x": 378,
#         "y": 799
#       },
#       {
#         "x": 538,
#         "y": 799
#       },
#       {
#         "x": 538,
#         "y": 854
#       },
#       {
#         "x": 378,
#         "y": 854
#       }
#     ],
#     "id": "1.1.22",
#     "text": "CALIFORN OF THE . sc"
#   },
#   {
#     "average_confidence": 0.9189342,
#     "bounding_box": [
#       {
#         "x": 156,
#         "y": 842
#       },
#       {
#         "x": 203,
#         "y": 842
#       },
#       {
#         "x": 203,
#         "y": 894
#       },
#       {
#         "x": 156,
#         "y": 894
#       }
#     ],
#     "id": "1.1.23",
#     "text": "OF"
#   }
# ]
# ```
#
# Return your output as a single valid JSON object with **only the fields listed above**. Be precise. Do not guess unknown fields.
# Saved output to /Users/liann/workspace/herbarium-processor/tmp/processed_output_1757829079_IMG_2716.json
# Saved output to /Users/liann/workspace/herbarium-processor/tmp/processed_output_1757829079_IMG_2709.json
# Saved CSV to /Users/liann/workspace/herbarium-processor/tmp/test_working.csv

# %%
"""Step 5: Generating comparison report

You do NOT need to edit this section.
"""

from herbarium_processor.core.analysis.html_report_generator import HTMLReportGenerator

canonical_csv_path = "/Users/danielleward/Downloads/random_sample2.csv"
html_output_path = "tmp/html_report.html"

reporter = HTMLReportGenerator(
    canonical_csv_path=canonical_csv_path,
    test_csv_path=output_csv_path,
    html_output_path=html_output_path,
    prompt_builder=prompt_builder,
    system_instructions_path=system_instructions_path,
)

reporter.run_all()
