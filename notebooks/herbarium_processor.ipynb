# %%
"""
Herbarium Processor Notebook
========================

This notebook is designed to process images of herbarium specimen labels and parse data into designated fields using a prompt-based approach.
It includes steps for image processing, prompt configuration, and generating digitized specimen data.
It is structured to be run in a Jupyter notebook environment.

Configuration: select what images to sample from.

You should edit this section each time you run the code to:
  * select the images you want to process
  * set the path to the output CSV file.
"""

from utils.notebook_setup import setup_project
setup_project()

image_path = "data/img/bucket"
output_csv_path = "tmp/an_output.csv"
# Out:
# Notebook root set to /Users/danielleward/Documents/Projects/herbarium-processor

# %%
"""
Configuration: setting up the prompts and system instructions for Gemini inference.

You do NOT need to edit this section.
"""
from herbarium_processor.core.inference.prompt_factory import create_prompt_builder_from_yaml

system_instructions_path = "prompts/ocr_system_instructions_no_citations.md"
prompt_builder = create_prompt_builder_from_yaml("prompts/configs/default_prompt.yaml")

print('Prompt:')
print(prompt_builder.generate_debug_prompt())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 6
#       1 """
#       2 Configuration: setting up the prompts and system instructions for Gemini inference.
#       3
#       4 You do NOT need to edit this section.
#       5 """
# ----> 6 from herbarium_processor.core.inference.prompt_factory import create_prompt_builder_from_yaml
#       8 system_instructions_path = "prompts/ocr_system_instructions_no_citations.md"
#       9 prompt_builder = create_prompt_builder_from_yaml("prompts/configs/default_prompt.yaml")
#
# File ~/Documents/Projects/herbarium-processor/src/herbarium_processor/core/inference/__init__.py:1
# ----> 1 from .prompt_builder import PromptBuilder
#       2 from .prompt_factory import create_prompt_builder_from_yaml
#       4 __all__ = ["PromptBuilder", "create_prompt_builder_from_yaml"]
#
# File ~/Documents/Projects/herbarium-processor/src/herbarium_processor/core/inference/prompt_builder.py:4
#       2 import json
#       3 import os
# ----> 4 from jinja2 import Environment, FileSystemLoader
#       5 from typing import List, Dict, Tuple
#       6 import re
#
# ModuleNotFoundError: No module named 'jinja2'

# %%
"""
Step 1: Image processing.

Download the .jpeg images from Collection Space. Open the images and use the Collection Space download button to ensure high quality images.
"""
from herbarium_processor.core.image.image_utils import (
    process_directory_no_auto_rotate
)

process_directory_no_auto_rotate(image_path)

# %%
"""
Step 2: Calling the OCR AI model.
This step will call OCR and save the output to .json files in the tmp/ directory.

It will then build specimen labels based on the OCR output.
You do NOT need to edit this section.
"""

import json
import sys
import os
from herbarium_processor.core.ocr.ocr_client import OcrClient

ocr = OcrClient()

if image_path:
  for filename in os.listdir(image_path):
    path = os.path.join(image_path, filename)
    if filename.lower().endswith(".jpg") or filename.lower().endswith(".jpeg"):
      print(f"Processing {path}")
      ocr.extract_text_json(path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 12
#      10 import sys
#      11 import os
# ---> 12 from herbarium_processor.core.ocr.ocr_client import OcrClient
#      14 ocr = OcrClient()
#      16 if image_path:
#
# File ~/Documents/Projects/herbarium-processor/src/herbarium_processor/core/ocr/ocr_client.py:1
# ----> 1 from google.cloud import vision
#       2 import io
#       3 import os
#
# ModuleNotFoundError: No module named 'google'

# %%
"""
Step 3: Building the samples for the prompt based on the OCR output.

This section will automatically generate the list of specimen labels
based on the sampled paths defined above.

You do NOT need to edit this section.
"""

from herbarium_processor.core.types.specimen_label import SpecimenLabel
from pathlib import Path

target_examples = []

if image_path:
  for filename in os.listdir(image_path):
    path = Path(os.path.join(image_path, filename))
    label = SpecimenLabel(
            id=path.stem,
            img_path=str(path),
            ocr_path=f"tmp/ocr_ai_input_{path.stem}.json"
        )
    target_examples.append(label)
    print("Saving specimen label with the following info:" + str(label))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 10
#       1 """
#       2 Step 3: Building the samples for the prompt based on the OCR output.
#       3
#    (...)
#       7 You do NOT need to edit this section.
#       8 """
# ---> 10 from herbarium_processor.core.types.specimen_label import SpecimenLabel
#      11 from pathlib import Path
#      13 target_examples = []
#
# File ~/Documents/Projects/herbarium-processor/src/herbarium_processor/core/types/specimen_label.py:3
#       1 from dataclasses import dataclass
# ----> 3 from herbarium_processor.config import ROOT_DIR
#       5 @dataclass
#       6 class SpecimenLabel:
#       7     id: str
#
# File ~/Documents/Projects/herbarium-processor/src/herbarium_processor/config.py:20
#      17 # tmp paths
#      18 TMP_DIR = ROOT_DIR / "tmp"
# ---> 20 def resolve_path(p: str | Path) -> Path:
#      21     p = Path(p)
#      22     return p if p.is_absolute() else ROOT_DIR / p
#
# TypeError: unsupported operand type(s) for |: 'type' and 'type'

# %%
"""
Step 4: Calling the AI model

You do NOT need to edit this section.
"""

from herbarium_processor.core.inference.label_extraction_batch_runner import LabelExtractionBatchRunner

runner = LabelExtractionBatchRunner(
    output_csv_path=output_csv_path,
    system_instructions_path=system_instructions_path,
    prompt_builder=prompt_builder,
    targets=target_examples
)
runner.run()
