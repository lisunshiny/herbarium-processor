# %%
from utils.notebook_setup import setup_project

setup_project()

image_dir = "data/img/06162025"

# %%
from herbarium_processor.config import ROOT_DIR
from herbarium_processor.core.image.image_utils import process_directory

# if something is wrong, use magick data/img/06162025/IMG_3169.jpg -rotate 180 -strip data/img/06162025/IMG_3169.jpg
process_directory(image_dir)
