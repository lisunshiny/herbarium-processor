# %%
shot_data = [
    {
        "id": "cs_16625_23",
        "img_path": "../../data/img/cs/cs_16625_23.jpg",
        "ocr_path": "../../tmp/ocr_ai_input_cs_16625_23.json",
    },
]
target_data = {
    "id": "cs_16625_19",
    "img_path": "../../data/img/cs/cs_16625_19.jpg",
    "ocr_path": "../../tmp/ocr_ai_input_cs_16625_19.json",
}
field_list = [
    "label_header",
    "scientific_name",
    "field_collection_location_verbatim",
    "county",
    "state",
    "country",
    "verbatim_latitude",
    "verbatim_longitude",
    "elevation",
    "habitat_information",
    "field_collection_date",
    "comment",
    "field_collectors",
    "identifier",
    "field_collection_number",
    "identification_date",
    "exsiccatae_number",
    "associated_taxa",
]
csv_path = "../../data/cs_canonical.csv"
template_path = "../prompts/templates/herbarium_prompt.j2"

# %%
import json
import sys
import os

# Ensure the root path is in sys.path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../")))

from notebooks.tools.ai_prompt_generator import (
    generate_prompt
)

prompt = generate_prompt(
    csv_path=csv_path,
    field_list=field_list,
    shot_data=shot_data,
    target_data=target_data,
    template_path=template_path
)

print(prompt)

# %%
import ai_prompt_generator

# %load_ext autoreload
# %autoreload 2
