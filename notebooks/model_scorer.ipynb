# %%
canonical_csv_path = "data/cs_canonical.csv"
test_csv_path = "tmp/liann_test_tempalated.csv"

# stuff needed for html generation
test_prompt = "prompts/few_shot_prompt_no_ocr.md"
test_system_instructions = "prompts/system_instructions_no_ocr.md"
html_output_path = "tmp/gemini_output_test_20.html"

# %%
from herbarium_processor.core.inference.prompt_builder import PromptBuilder
from herbarium_processor.core.types.specimen_label import SpecimenLabel

system_instructions_path = "prompts/ocr_system_instructions_no_citations.md"
few_shot_csv_path = "data/cs_canonical.csv"
field_list = [
    "label_header",
    "scientific_name",
    "field_collection_location_verbatim",
    "county",
    "state",
    "country",
    "verbatim_latitude",
    "verbatim_longitude",
    "elevation",
    "habitat_information",
    "field_collection_date",
    "comment",
    "field_collectors",
    "identifier",
    "field_collection_number",
    "identification_date",
    "exsiccatae_number",
    "associated_taxa",
]
few_shot_labels = [
    SpecimenLabel(
        id="cs_16625_23",
        img_path="data/img/cs/cs_16625_23.jpg",
        ocr_path="tmp/ocr_ai_input_cs_16625_23.json",
    ),
    SpecimenLabel(
        id="cs_16625_24",
        img_path="data/img/cs/cs_16625_24.jpg",
        ocr_path="tmp/ocr_ai_input_cs_16625_24.json",
    ),
    SpecimenLabel(
        id="cs_16625_25",
        img_path="data/img/cs/cs_16625_25.jpg",
        ocr_path="tmp/ocr_ai_input_cs_16625_25.json",
    ),
]

target_example = SpecimenLabel(
    id="cs_16625_19",
    img_path="data/img/cs/cs_16625_19.jpg",
    ocr_path="tmp/ocr_ai_input_cs_16625_19.json",
)

few_shot_prompt_path = "prompts/few_shot_prompt_rich.md" # todo remove
prompt_template = "prompts/templates/herbarium_prompt.j2"
prompt_builder = PromptBuilder(
    csv_path=few_shot_csv_path,
    field_list=field_list,
    shot_data=few_shot_labels,
    template_path=prompt_template)

# %%
import sys
import os

from herbarium_processor.core.analysis.html_report_generator import HTMLReportGenerator

reporter = HTMLReportGenerator(
    canonical_csv_path=canonical_csv_path,
    test_csv_path=test_csv_path,
    html_output_path=html_output_path,
    prompt_builder=prompt_builder,
    system_instructions_path=test_system_instructions
)

reporter.run_all()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 6
#       2 import os
#       4 from herbarium_processor.core.analysis.html_report_generator import HTMLReportGenerator
# ----> 6 reporter = HTMLReportGenerator(
#       7     canonical_csv_path=canonical_csv_path,
#       8     test_csv_path=test_csv_path,
#       9     html_output_path=html_output_path,
#      10     prompt_builder=prompt_builder,
#      11     system_instructions_path=test_system_instructions
#      12 )
#      14 reporter.run_all()
#
# File ~/Documents/Projects/herbarium-processor/src/herbarium_processor/core/analysis/html_report_generator.py:61, in HTMLReportGenerator.__init__(self, canonical_csv_path, test_csv_path, html_output_path, prompt_builder, system_instructions_path)
#      59 self.system_instructions_path = ROOT_DIR / system_instructions_path
# ...
