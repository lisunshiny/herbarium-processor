# %%
from utils.notebook_setup import setup_project
setup_project()

from herbarium_processor.core.types.specimen_label import SpecimenLabel

target_example = SpecimenLabel(
    id="cs_16625_19",
    img_path="data/img/cs/cs_16625_19.jpg",
    ocr_path="tmp/ocr_ai_input_cs_16625_19.json",
)

# %%
from herbarium_processor.core.inference.prompt_builder import PromptBuilder
from herbarium_processor.core.inference.prompt_factory import create_prompt_builder_from_yaml

builder = create_prompt_builder_from_yaml("prompts/configs/default_prompt.yaml")

prompt2, image_paths = builder.generate(target_example)
print(prompt2)
print(image_paths)
